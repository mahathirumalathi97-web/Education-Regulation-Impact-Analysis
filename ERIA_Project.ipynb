# %% [markdown]
# <a href="https://colab.research.google.com/github/mahathirumalathi97-web/Education-Regulation-Impact-Analysis/blob/main/ERIA_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Education Regulation Impact Analaysis

# %% [markdown]
# # Install Libraries

# %%
# !pip install PyPDF2
# !pip install pdfplumber
# !pip install nltk
# !pip install groq
# !pip install gensim
# Out:
# Collecting PyPDF2
#   Downloading pypdf2-3.0.1-py3-none-any.whl.metadata (6.8 kB)
# Downloading pypdf2-3.0.1-py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-3.0.1
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.9-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 565.0 kB/s eta 0:00:00
# Collecting pdfminer.six==20251230 (from pdfplumber)
#   Downloading pdfminer_six-20251230-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.12/dist-packages (from pdfplumber) (11.3.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber)
#   Downloading pypdfium2-5.8.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (68 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.4/68.4 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (3.4.7)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20251230->pdfplumber) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20251230->pdfplumber) (3.0)
# Downloading pdfplumber-0.11.9-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 2.6 MB/s eta 0:00:00
# Downloading pdfminer_six-20251230-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 17.4 MB/s eta 0:00:00
# Downloading pypdfium2-5.8.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 15.8 MB/s eta 0:00:00
# Installing collected packages: pypdfium2, pdfminer.six, pdfplumber
# Successfully installed pdfminer.six-20251230 pdfplumber-0.11.9 pypdfium2-5.8.0
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)
# Collecting groq
#   Downloading groq-1.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.13)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)
# Downloading groq-1.2.0-py3-none-any.whl (142 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.3/142.3 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: groq
# Successfully installed groq-1.2.0
# Collecting gensim
#   Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.6.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# Downloading gensim-4.4.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 45.2 MB/s eta 0:00:00
# Installing collected packages: gensim
# Successfully installed gensim-4.4.0

# %%
import nltk
nltk.download('punkt')
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %% [markdown]
# # Data Handling Libraries

# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.stem import PorterStemmer
import re
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# %%
import PyPDF2

# List of PDF files (correct way)
pdf_file_paths = [
    "/content/1601817_F.No.-2-25-2024(CPP-II).pdf",
    "/content/3813291_Advisory-Safety-and-Security-of-the-Students.pdf",
    "/content/6493421_UGC-Guidelines-pursuing-two-academic-programmes-simultaneously.pdf",
    "/content/8091137_gazette-antiragging-Second-Amendment.pdf",
    "/content/Notification_9_1-2022-U_3A.pdf",
    "/content/8432142_UGC-Notice-reg.-Erasmus-Programmes.pdf",
    "/content/6579445_Public-Notice-Fake-University.pdf"
]

def extract_text_from_pdf(pdf_path):
    text = ""
    try:
        with open(pdf_path, 'rb') as file:
            reader = PyPDF2.PdfReader(file)
            for page in reader.pages:
                page_text = page.extract_text()
                if page_text:
                    text += page_text + "\n"
    except Exception as e:
        text = f"Error extracting text: {e}"
    return text

# Extract from all PDFs
all_text = ""

for path in pdf_file_paths:
    print(f"Processing: {path}")
    all_text += extract_text_from_pdf(path) + "\n\n"

print(all_text)
# Out:
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(180, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(175, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(170, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(165, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(160, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(155, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(150, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(145, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(140, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(135, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(130, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(125, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(120, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(115, 0, 133142163883648)]
# Processing: /content/1601817_F.No.-2-25-2024(CPP-II).pdf
# Processing: /content/3813291_Advisory-Safety-and-Security-of-the-Students.pdf
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(110, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(105, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(100, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(95, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(90, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(79, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(74, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(69, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(64, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(59, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(54, 0, 133142163883648)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(262, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(257, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(252, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(247, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(242, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(237, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(232, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(227, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(222, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(217, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(212, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(207, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(202, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(197, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(192, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(187, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(182, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(177, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(172, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(160, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(152, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(147, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(142, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(137, 0, 133142188165552)]
# Processing: /content/6493421_UGC-Guidelines-pursuing-two-academic-programmes-simultaneously.pdf
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(130, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(125, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(120, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(115, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(110, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(103, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(98, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(93, 0, 133142188165552)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(88, 0, 133142188165552)]
# Processing: /content/8091137_gazette-antiragging-Second-Amendment.pdf
# Processing: /content/Notification_9_1-2022-U_3A.pdf
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(729, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(724, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(719, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(714, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(709, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(704, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(699, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(694, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(689, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(684, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(679, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(674, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(669, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(664, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(659, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(654, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(649, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(644, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(639, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(634, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(629, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(624, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(619, 0, 133142404879936)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(614, 0, 133142404879936)]
# Processing: /content/8432142_UGC-Notice-reg.-Erasmus-Programmes.pdf
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(306, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(301, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(296, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(291, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(286, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(281, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(276, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(271, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(266, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(261, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(256, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(251, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(246, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(241, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(236, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(231, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(226, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(221, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(216, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(211, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(206, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(201, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(196, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(191, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(167, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(162, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(157, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(152, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(147, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(142, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(137, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(132, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(127, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(122, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(117, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(112, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(107, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(102, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(97, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(92, 0, 133142127672160)]
# Processing: /content/6579445_Public-Notice-Fake-University.pdf
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(87, 0, 133142127672160)]
# WARNING:PyPDF2._cmap:unknown widths :
# [0, IndirectObject(82, 0, 133142127672160)]
# &hQqRgr@ a3qTq wlMl
# University Grants Commission
# (f§RW tvrqq, vm nrr)
# (Ministry of Education, Govt. of India)
# #TglHTF asl wt, Hf eM-110002
# Bahodur Shah Zafar Marg, New Delhi-110002
# Ph., 01 1-23236288/23239337
# Fox , 01 1-2323 8858
# E-mail , secy.ugc@nic.inrn-fqgn fq3Ml
# ThT
# Secretary
# D.O.No. 2-25/2024(CPP-II)(C.144198) 2 aTV, 1947/ 22"d January, 2026
# Subject: Free of cost verification of the genuineness of the educational certificates.
# XTRWRTHdTTr/HORn
# This is in continuation of the UGC communication dated 30th May 2024, regarding the verification
# of educational certificates of newly recruited Assistant Section OfFicers (DRASOs) through the
# Combined Graduate Level Examination (CGLE) conducted by the Staff Selection Commission
# (SSC). A copy of the earlier communication is attached for reference.
# It is emphasized once again that verification of educational qualifications, in addition to other
# prescribed verifications, is a prerequisite for confirmation of the appointed officers in the
# Government service. In the interest of the Government, it is necessary to ensure the
# genuineness of candidates. Therefore, it should be the obligation of each educational institute,
# including private/deemed universities, to conduct this verification free of cost.
# Therefore, all the Central/State/Deemed/Private Universities and other Higher Education
# Institutions are hereby requested to undertake free of cost verification of the genuineness of the
# educational certificates for all recruitments to Central Government posts, irrespective of recruiting
# agency, whenever any Ministry/Department or any other Central Government organization
# makes a request to this effect.
# TIKI,
# 8TaaT,
# h:rb
# (qdbIRTa;T)
# +TT +,
# n+fBqafB@nHa + TnTfRI
# T18ft#61faqql,la + ylqIJI 1
#
# HIV
# ’i#
# m llm in#1
# VIVId qf+q r. ;it9ft
# undfqqqfiaTml ayn vram
# University Grants Commission
# T3r4T LiII]]. HIll A J+rJ
# (Ministry of Education. Govt. of !rldio) Prof. Manish R. Joshi
# Secretary
# D.O.No.2-25/2024(CPP-II) 30th May, 2024/ 09 Ma, 1946
# Subject: Free of cost verification of genuineness of the educational certificates.
# 3n€wh4 xdeTr/HdeT.
# As you are aware, the verification of Educational Qualification is a pre-requisite for
# confirmation of the appointed officers in the Government service. It is necessary in the
# interest of the Government to ensure the genuineness of the candidates, and hence,
# it should be the obligation of each educational institute, including private/deemed
# universities. to do this verification free of cost
# In this regard, it is stated that there have been several instances wherein educational
# institutions demanded fees for the verification of educational certificates of newly
# recruited Assistant Section Officers (DRASOs) through the Combined Graduate Level
# Examination (CGLE) conducted by the Staff Selection Commission (SSC)
# The Higher Education institutions are requested to verify the genuineness of the
# educational certificates of newly recruited ASOs in SSC free of cost whenever any
# Ministry/Department makes a request to that effect to undertake such verification
# TrTI,
# (xRv ahH)
# tH R,
# nfl fBq4fBana=# iT @;faI
# III& d$1fac,dIdO + yidIJ 1
# FV3TR Wr qm. n mt-1 t ti'III: Bahodur Shoh Zctor Morg Ne',v Delhi-110002
# TITH (Ph ): ai 1-23236288/23239337 wn pr ::+1) {E-lnail) secy.ugc:10nic.,il
#
#
#
# ffl,!-��
# � � �. iiITTft
# �
# Prof. Manish R. Joshi
# Secretary
# F.No. 1-47 /2026(ARC)�� 7C� /"� .........,;
# '311'511� cfil
# � ....... J.f $-� c-fi-....-,.q
# mc1i4sUW.f � 3TI1.fT1T
# University Grants Commission
# (�rur �. 'qffif �)
# (Ministry of Education, Govt. of India)
# 19 b / 1948 / 09 April, 2026
# Subject: Strict Compliance with UGC Regulations on Safety and Security
# of Students in Higher Educational Institutions (HEis) -reg.
# 311G�oflq l-li?JGql/�,
# The University Grants Commission (UGC) is committed to ensuring the safety
# and security of students. To ascertain the same, UGC has notified and issued
# various regulations and guidelines from time to time for ensuring the safety,
# security� and well-being of students in Hlgher Educational Institutions (HEis).
# Accordingly, all HEls are advised to strictly comply with the provisions of the
# following student-centric UGC regulations and guidelines:
# 1.UGC Regulations on Curbing the Menace of Ragging in Higher Educational
# Institutions, 2009 and its amendments.
# 2.UGC (Promotion of Equity in Higher Educational Institutions) Regulations,
# 2012.
# 3.UGC (Prevention, Prohibition and Redressal of Sexual Harassment of
# Women Employees and Students in HEis) Regulations, 2015.
# 4.UGC (Redressal of Grievances of Students) Regulations, 2023 -covering
# Student Grievance Redressal Committees (SGRC) and appointment of
# Ombudsperson.
# 5.University Grants Commission guidelines on Refund of Fees and Non­
# Retention of Original Certificates.
# 6.UGC Guidelines for Promotion of Physical Fitness, Sports, Students'
# Health, Welfare, Psychological and Emotional Well-Being.
# 7.Other guidelines/advisories issued by UGC from time to time, including
# institutional responsibilities under various regulations.
# �m � lWT, '::rt �-110002 I Bahadur Shah Zafar Marg, New Delhi-110002
# � (Ph.): 011-23236288/23239337 I � Wf ({�) (E-mail): secy.ugc@nic.in-Continued-
# All institutions are further advised to:
# 1.Ensure the constitution and effective functioning of various committees and
# cells such as the Anti-Ragging Committee, Internal Complaints Committee
# (ICC), Equal Opportunity Cell, and Grievance Redressal Cell, etc. The details
# of these committees shall be duly uploaded/updated on the HEis' official
# website on regular basis.
# 2.Establish robust, transparent, and time-bound grievance redressal
# mechanisms.
# 3.Strengthen student support systems, including counselling services and
# mental health support.
# 4.Ensure adequate campus safety measures, .including CCTV surveillance
# and security arrangements.
# 5.Conduct regular sensitization and awareness programmes for students and
# staff.
# 6.Maintain proper records of committee meetings and action taken reports.
# 7.Provide necessary support forvulnerable and differentl y-abled students.
# The concerned may regularly visit the official website of the University Grants
# Commission at https: / /www.ugc.ac.in/ to access and review the latest guidelines,
# circulars, regulations, and other updates issued in the public domain.
# All Vice-Chancellors are requested to direct the Colleges under their jurisdiction
# to take necessary action in this regard and ensure strict compliance with the
# above provisions.
# �.
# �fa1�e1a,li a, gsaqRt 1
# � Jt(sl�QldQl��I
#
#
# ��'{. �ft
# �
# Prof. Manish R. Joshi
# Secretary
# D.0. No.F.1-6/2007 (CPP-ll)(Comp.No.108737),;::::-� -,��> •..,; '31-,':11-, ej-cfif-----� --3Pfl '-1$1�q
# fficl�UIW-4 � �
# University Grants Commission
# (�Tm�. 'qJ«f "fficJiR)
# (Ministry of Education, Govt. of India)
# 15� 1947/ SthJune, 2025
# The Commission in its 589th meeting held on 3rd April 2025 has approved partial modification of
# the UGC Guidelines for Pursuing Two Academic Programmes Simultaneously. The details of the
# same are as follows:
# The existing provision in point no. 5 of the The modification approved by the
# guidelines Commission in point no. 5 of the guidelines
# These guidelines shall come into effect from
# the date of their notification by the UGC. No
# retrospective benefit can be claimed by the
# students who have already done two
# academic programmes simultaneously prior to
# the notification of these guidelines. These guidelines shall come into effect from
# the date of their notification by the UGC.
# Provided that two academic programmes,
# pursued simultaneously, before issuing of
# these guidelines, in accordance with the UGC
# First Degree and Master Degree Regulations,
# statutes/ordinances of the university/
# universities concerned, and by following the
# norms prescribed by the statutory professional
# council(s) and the Distance Education Council/
# Distance Education Bureau of the UGC,
# wherever applicable, shall be treated as valid.
# Accordingly, a copy of the modified version of the Guidelines for Pursuing Two Academic
# Programmes Simultaneously is enclosed herewith for reference.
# All universities and their affiliated colleges/institutions are requested to implement these
# guidelines for the benefit of the students.
# �.
# �lf.
# �f3ft fcl�c1fcle;.Qlcl.zr'i � cficlqffi I � �
# lf3ft A(<lfcle;__.t11cl:zr'i <Ti �I
# �m- � 1'11l, � �-110002 I Bahadur Shah Zafar Marg, New Delhi-110002
# � (Ph.): Oll-23236288/23239337 I � � (t�) (E-mail): secy.ugc@nic.in
# Guidelines for Pursuing Two Academic Programmes
# Simultaneously
# University Grants Commission
# Bahadur Shah Zafar Marg
# New Delhi
# April, 2025
# .
# ;
# Guidelines for Pursuing Two Academic Programmes
# Simultaneously
# Background
# The National Education Policy -NEP 2020 states that pedagogy
# must evolve to make education more experiential, holistic,
# integrated, inquiry-driven, discovery-oriented, learner- centred,
# discussion-based, flexible, and, of course, enjoyable. The policy
# envisions imaginative and flexible curricular structures to enable
# creative combinations of disciplines for study, that would offer
# multiple entry and exit points, thus, removing currently prevalent
# rigid boundaries and creating new possibilities for life-long learning
# and centrally involve critical and interdisciplinary thinking.
# With the rapid increase in demand for higher education and
# limited availability of seats in regular stream, several Higher
# Education Institutions (HEis) have started a number of programmes
# in Open and Distance Learning (ODL) mode to meet the aspirations
# of students. It has also led to the emergence of online education
# programmes which a student can pursue within the comforts of her/
# his home. The issue of allowing the students to pursue two academic
# programmes simultaneously has been examined by the Commission
# keeping in view the proposals envisaged in the National Education
# Policy -NEP 2020 which emphasizes the need to facilitate multiple
# pathways to learning involving both formal and non-formal education
# modes.
# In view of above, UGC has framed the following Guidelines.
# Objectives
# To allow the students to pursue two academic programmes
# simultaneously keeping in view the following objectives envisaged in NEP
# 2020:
# 1
# l
# •recognizing, identifying, and fostering the unique
# capabilities of each student, by sensitizing teachers as
# well as parents to promote each student's holistic
# development in both academic and non-academic
# spheres;
# •no hard separations between arts and sciences, between
# curricular and extra- curricular activities, between
# vocational and academic streams, etc. in order to
# eliminate harmful hierarchies among, and silos between
# different areas of learning;
# •multidisciplinarity and a holistic education across the
# sciences, social sciences, arts, humanities, and sports for
# a multidisciplinary world in order to ensure the unity and
# integrity of all knowledge;
# •enabling an individual to study one or more specialized
# areas of interest at a deep level, and also develop
# character, ethical and constitutional values, intellectual
# curiosity, scientific temper, creativity, spirit of service.
# •offering the students, a range of disciplines including
# sciences, social sciences, arts, humanities, languages, as
# well as professional, technical, and vocational subjects to
# make them thought ful, well-rounded, and creative
# individuals.
# •preparing students for more meaningful and satisfying
# lives and work roles and enable economic independence.
# Guidelines
# 1.A student can pursue two full time academic programmes in
# physical mode provided that in such cases, class timings for one
# programme do not overlap with the class timings of the other
# programme.
# 2
# 2.A student can pursue two academic programmes, one in full time
# physical mode and another in Open and Distance Learning
# (ODL)/Online mode; or up to two ODL/Online programmes
# simultaneously.
# 3.Degree or diploma programmes under ODL/Online mode shall be
# pursued with only such HEis which are recognized by
# UGC/Statutory Council/Govt. of India for running such
# programmes.
# 4.Degree or diploma programmes under these guidelines shall be
# governed by the Regulations notified by the UGC and also the
# respective statutory/professional councils, wherever applicable.
# 5.These guidelines shall come into effect from the date of their
# notification by the UGC.
# Provided that two academic programmes, pursued simultaneously,
# before issuing of these guidelines, in accordance with the UGC First
# Degree and Master Degree Regulations, statutes/ordinances of the
# university/ universities concerned, and by following the norms
# prescribed by the statutory professional council(s) and the
# Distance Education Council/Distance Education Bureau of the UGC,
# wherever applicable, shall be treated as valid.
# The above guidelines shall be applicable only to the
# students pursuing academic programmes other than Ph.D.
# programme.
# Based on the above guidelines, the universities can devise mechanisms,
# through their statutory bodies, for allowing their students to pursue two
# academic programmes simultaneously as mentioned above.
# 3
#
#
# University Grants Commission
# University Grants Commission
# curbing the Menace of Ragging in Higher Educational Institutions
# (second Amendment) Regulations, 2013.
# NOTIFICATION
# New Delhi, the 25th December, 2013
# No. F. 15-3/2013 (ARC) Pt. III-In exercise of powers conferred under clause (g) of sub-section
# (1) of section 26 of the University Grants Commission Act 1956 (3 of 1956), the University
# Grants Commission hereby makes the following regulations, namely:-
# (1) These regulations may be called the “curbing the Menace of Ragging in Higher
# Educational Institutions (second Amendment) Regulations, 2013”.
# (2) They shall come into force on the date of their publication in the Official Gazette.
# 2. In UGC Regulations on Curbing the Menace of Ragging in Higher Educational Institutions,
# 2009, (hereinafter referred to as the Principal regulations), in the Annexure-I and II of the
# regulations, the sentences containing the following shall be deleted:
# “Solemnly affirmed and signed in my presence on this (day)of (month), (year) after
# reading the contents of this affidavit.
# OATH COMMISSIONER”
# UPAMANYU BASU, Secy.
# (ADVT. III/4/Exty./113/13])
# Foot Note: The principal Regulations were published in the Gazette of India, vide notification number 27 dated 04.07.2009.
# UGC Regulations
# ANNEXURE-I
# UNDERTAKING BY THE STUDENT
# I, (full name of student with admission/registration/enrolment number) s/o d/o Mr./Mrs./Ms.
# having been admitted to (name of the institution) have received a copy of the UGC Regulations on Curbing the Menace of Ragging in Higher Educational Institutions, 2009, (hereinafter called the
# Regulations”) carefully read and fully understood the provisions contained in the said Regulations.
# (2) I have, in particular, perused clause 3 of the Regulations and am aware as to what constitutes
# ragging.
# (3) I have also, in particular, perused clause 7 and clause 9.1 of the Regulations and am fully
# aware of the penal and administrative action that is liable to be taken against me in case Iam found guilty of or abetting ragging, actively or passively, or being part of a conspiracy to
# promote ragging.
# (4) I hereby solemnly aver and undertake that
# (a) I will not indulge in any behaviour or act that may be constituted as ragging under
# clause 3 of the Regulations.
# (b) I will not participate in or abet or propagate through any act of commission or omission
# that may be constituted as ragging under clause 3 of the Regulations.
# (5) I hereby affirm that, if found guilty of ragging, I am liable for punishment according to clause
# 9.1 of the Regulations, without prejudice to any other criminal action that may be taken
# against me under any penal law or any law for the time being in force.
# (6) I hereby declare that I have not been expelled or debarred from admission in any institution
# in the country on account of being found guilty of, abetting or being part of a conspiracy topromote, ragging; and further affirm that, in case the declaration is found to be untrue, I amaware that my admission is liable to be cancelled.
# Declared this _________ day of_________ month of _________year.
# Signature of deponent Name:
# VERIFICATION
# Verified that the contents of this undertaking are true to the best of my knowledge and no part of the undertaking is false and nothing has been concealed or misstated therein.
# Verified at_________(place)on this the_________(day) of_________(month)________(year)
# Signature of deponent Name:
# University Grants Commission
# UNDERTAKING BY PARENT/GUARDIAN
# ANNEXURE-II
# I, Mr./Mrs./Ms. (full name of parent/guardian) father/mother/guardian of, (full name of student
# with admission / registration/enrolment number) having been admitted to (name of the Institution) have received a copy of the UGC Regulations on Curbing the Menace of Ragging in Higher Educational Institutions, 2009, (hereinafter called the “Regulations”), carefully read and fully understood the provisions contained in the said Regulations.”
# (2) I have, in particular, perused clause 3 of the Regulations and am aware as to what constitutes
# ragging.
# (3) I have also, in particular, perused clause 7 and clause 9.1 of the Regulations and am fully
# aware of the penal and administrative action that is liable to be taken against my ward in
# case he/she is found guilty of or abetting ragging, actively or passively, or being part of a
# conspiracy to promote ragging.
# (4) I hereby solemnly aver and undertake that
# (a) My ward will not indulge in any behaviour or act that may be constituted as ragging
# under clause 3 of the Regulations.
# (b) My ward will not participate in or abet or propagate through any act of commission or
# omission that may be constituted as ragging under clause 3 of the Regulations.
# I hereby affirm that, if found guilty of ragging, my ward is liable for punishment according to
# clause 9.1 of the Regulations, without prejudice to any other criminal action that may be taken
# against my ward under any penal law or any law for the time being in force.
# THE GAZETTE OF INDIA: EXTRAORDINARY  (PART III-SBC. 4)
# (6) I hereby declare that my ward has not been expelled or debarred from admission in any
# institution in the country on account of being found guilty of, abetting or being part of a
# conspiracy to promote, ragging; and further affirm that, in case the declaration is found to be
# untrue, the admission of my ward is liable to be cancelled.
# Declared this _________ day of_________ month of _________year.
# Signature of deponent
# Name:
# Address: Telephone/Mobile No.:
# VERIFICATION
# Verified that the contents of this undertaking are true to the best of my knowledge and no part of
# the undertaking is false and nothing has been concealed or misstated therein.
# Verified at_________(place) on this the_________(day) of_________(month)________(year)
# Signature of deponent Name:
#
#
# lTo BE PUBLTSHED rN THE GAZETTE OF rNDrA PART-I SECTTON-II
# Government of India (Bharat Sarkar)
# Ministry of Education fSiksha Mantralaya)
# Department of Higher Education (Uchchatar Siksha Vibhag)
# ICR Division
# Kartavya Bhawan-Z, New Delhi
# Dated: 30tr March,2026
# NOTIFICATION
# No.9-l/2O22-U.3(A): Whereas, the Central Government is empowered under Section
# 3 of the University Grants Commission [UGC) Act, 1956 to declare, on the advice of the
# UGC, an Institution of higher learning as an Institution deemed to be University.
# 2. And whereas, an online application was uploaded on UGC Portal for grant of
# Institution deemed to be University status under distinct category to National Council of
# Educational Research and Training (NCERT), Sri Aurobindo Marg, New Delhi with the
# following six constituent units under Section 3 of the UGC Act, L956.
# L
# ii.
# i ii.
# iv.
# V.
# vi.Regional Institute of Education, Ajmer, Rajasthan
# Regional Institute of Education, Bhopal, Madhya Pradesh
# Regional Institute of Education, Bhubaneswar, Odisha
# Regional Institute of Education, Manasagangotri, Mysore, Karnataka
# North East Regional Institute of Education, Shillong, Meghalaya
# Pandit Sunderlal Sharma Central Institute of Vocational Education, Bhopal,
# Madhya Pradesh.
# 2. And whereas, UGC, vide letter No.L9-l/2022 (CPP-I/DU) dated LL.L0.2022 and
# subsequent clarification dated 28.08.2023, recommended for issuance of Letter to
# Intent [Lol) to NCERT with certain conditions. The recommendation of the UGC Expert
# Committee was considered and approved by the Commission.
# 3. And whereas, the Ministry of Education, on the advice of UGC, issued Letter of
# Intent (Lol) dated 31.08.2023 to NCERT, New Delhi for fulfilment of certain conditions
# within a period of three years before declaration of NCERT, New Delhi as an Institution
# deemed to be University.
# 4. And further whereas, the Institution, vide letter dated 04.L1.2025, submitted
# compliance report of the conditions of the Lol which was sent to UGC for verification
# and its advice. UGC informed that the compliance report was accepted by its Expert
# Committee. The recommendation of UGC Expert Committee was considered and
# approved by the Commission in its 595th meeting (ltem No. 2.15J held on 30.0L.2026.
# 5. Now, therefore, in exercise of powers conferred under Section 3 of the UGC Act,
# L956, the Ministry of Education, on the advice of the UGC, hereby declares National
# e*".
# Council of Educational Research and Training, Sri Aurobindo Marg, New Delhi
# consisting of above mentioned six constituent units as an Institution deemed to be
# University under distinct category. The said declaration is subject to the following
# conditions:
# i. There shall be no diversion of assets or funds/revenues of the Institution
# Deemed to be University/or of its constituent teaching units, without prior
# permission of the UGC and Central Government.
# ii. NCERT, New Delhi shall not engage or indulge in any activities that are of
# commercial and profit making in nature.
# iii. The academic programmes to be offered at NCERT, New Delhi shall conform tothe norms and standards prescribed by the UGC and the Statutory
# Councils/Bodies concerned.
# iv. NCERT, New Delhi shall start new academic Courses/Programmes, Off-
# Campus(es), Off-Shore Campus(es) only in accordance with the norms and
# guidelines issued by the UGC, from time to time, on the subject.
# v. NCERT, New Delhi shall take appropriate steps to commence research
# programmes as well as doctoral and innovative academic programmes. The
# Institute shall not keep confined only to presently new emerging areas but make
# endeavour to expand in other areas in accordance with the UGC Regulations /
# Guidelines as well as National Education Policy-2020.
# vi. NCERT, New Delhi shall take all the required steps to get all the eligible academic
# courses/programmes rated for valid accreditation by National Board of
# Accreditation (NBA) and the Institute to get valid accreditation by National
# Assessment and Accreditation Council [NAAC), as the case may be, in terms of
# the provisions as contained in the UGC (lnstitutions Deemed to be Universities)
# Regulations,2023, as amended from time to time.
# vii. All the prescribed norms and procedures of the Statutory Councils concerned in
# the matter of admission of students, intake capacity of students, renewal of
# approval to the academic course / programme, revision of intake capacity of
# students, starting of new courses / programmes, etc. shall continue to be in force,
# and shall be adhered to by National Council of Educational Research and
# Training (NCERT), Sri Aurobindo Marg, New Delhi.
# viii. NCERT, New Delhi shall submit its revised Memorandum of Association [MoA) /
# Rules to UGC/M|nistry of Education as per the provisions of the UGC (lnstitutions
# deemed to be Universities) Regulations, 2023 at the earliest. As and when
# necessary, the Institute shall update or revise or modify its MoA / Rules, as per
# the provisions of the prevailing Regulations.
# ix. NCERT, New Delhi shall follow the fee structure as per the Rules and Regulations
# of the UGC and relevant Statutory Councils.
# x. NCERT, New Delhi shall participate in annual Indian rankings issued by National
# Institutional Ranking Framework (NIRF) of this Ministry.
# Ii,^a
# xiNCERT, New Delhi shall compulsorily create Academic Bank of Credits (ABC),
# identities of their students and upload their credit score in digital lockers and
# ensure that the credit scores are reflected in ABC Portal and adopt Samarth e-
# Gov.N
# fPurnendu Kishore Banerjee)
# f oint Secretary to the Govt. of India
# Tel | +9L LL 24015038
# The Manager,
# Government of India Press,
# Minto Road, New Delhi - 110002
# Copy forwarded to:
# 1. The Secretary, Department of School Education & Literacy, Ministry of Education,
# New Delhi.
# 2. The Secretary, University Grants Commission, Bahadurshah Zafar Marg, New
# Delhi - 110002.
# 3. The Member Secretary, All India Council for Technical Education [AICTE), Nelson
# Mandela Marg, Vasant Kunj, New Delhi-110070.
# 4. The Director, NCERT, Sri Aurobindo Marg, New Delhi.
# 5. Press Information Bureau, Shastri Bhawan, New Delhi-110001.
# 6. The Secretary-General, Association of Indian Universities, A.l.U. House, 16, Kotla
# Marg, New Delhi - 110002.
# 7. f oint Director (Administration) & Web Master, Department of Higher Education,
# Shastri Bhawan, New Delhi with the request to issue necessary instructions to
# the CMIS Unit to display this notification on the website of Department of Higher
# Education.
# B. PS to Hon'ble EM
# 9. Guard file / Notification file.
# [fyoti
# Under Secretary to the Govt.
# Tel i +9L LL 240'J,4923n)
# ofia
# tfircr *'{IEFFT $[TaT-I Gig-l ci Trfirrrdn{l
# E{r{A H{dFR
# fe-Tqnr FiTrtrT
# r.,rkr{ f,q}qil tr?Trq
# srffttrq sfilTr+
# FderT etrd -2,;r+ ffi
# hiq': 30 a+rf, 2026
# 3Tmq'{dr
# ,i. g-1t2022-T,.3(3T): ;r{fr', *a rr+rr at FaqqErqffiq 3rry 3Tr*rr qmfr)
# 3rfrh?rq, 1950 fir emr s t ilid fuqf{fircrq srEelra 3Tr*rr frr ssro w FftR
# firerr {'Fra m} sq-fraEf*crnrq :iTen *'sq fr dFa *1il qr 3{fufirr srq Hl
# 2. sik r{fu, fuafu-curau Jqen;r 3{rd?r 3{EGqff, 1950 fi t r{r 3 fi 3ipt6
# Frqftft6 66 Er-s ilflgut *' srq {rserq rlffio sr{Stffi q?i qft}qrur qntw
# tq-+Strnrel, * srffi ,n 1', d$ fr.ofr 6t Eft'Ise Elufr * 3iilrta sq-fuiEfu<+rorq
# m eul'rtr;T 6Tfr fi fr('TtrI dta q{ ('rfi' #ffiSfr 3Trtfr 3lqatE frqr urqrt
# i.
# ii.
# iii.
# iv.
# V.
# vi.et{rq Rreil TiT?r-;T, 3r;rf{, {rd€2ffir
# q-t{rq Rrerr ri+errd, aisril, z+eq rerr
# qi{rq fi'rq.Tr riT?rFr, t-{e?*r, siBqn
# ettrq R'ten {iTerrr, qFr€"i?ffr, flq{, q;at?i6
# Td"{ q14q Rrqn {iF?rFT, Rrili+, frqrr+
# .iffd gtrr.fla qrd'ihffq eqlrgrfu{. RIeTr riT?IFI, atqlFr, quq qa?n
# z. silr;rqfu, qm i fif,ifr 11.10.2022 t q*:iEqr 19-1t2022 (Sfrfr-rfrT)
# *.qlq 6 p6iq; 28.08.2023 6 sqs.effrTur * qB,ryq t go rrd * srar qErS*TrfA
# Eil snlrq q* (tqsfr:nfl dfi *,rA 4T ffiqr firt q-JrS Fd*qH TrEfr fir ffier
# .rr snqta EqRr ffdr tr;qr arqr 3it-{ {$ sEdBa fuqr erqrt
# 3. rik rqfu, f,*eilr drffiq fr q-ffi fir +ren * o4$$lnr&, ;rt fr."fr +t sq
# fuak-c+rc+ :dr?ila fi sq fr q)frd m,rfr t qFA Aa Et *r rrdfr * aftn go
# qrd at qrr mri * fr(' (ES$Trr8I, n$ friofr m,] froifi 31.08.2023 *t rnerq q{
# (('ffifun$) art fuqr' **
# 4. 3itT 3Trn uiirft', dT?ra i Aaiq, 04.11 .202s *' qx *' qrtse t r-a:furr5 fir
# rff *r rry mt er-g1 frt, m ry $k rarO * fr('q-ffi 6t eiil
# ereTt {ffi i qfud fuqr f*. %dqrera frdt qrt 3rr€r fr?tv-fr sfrft EERr do'R
# q-r frqrcraT1 Wffi E?tcrf, TrRfr {lr fuwft?r qr nr*er ildrr f{ai+, 30.01 .2020
# 6t 6* 3Tqff 595fi t6fi Gr{ :ilar 2.15) fr fuER F+n erqr 3lt{ s-@frH F+-qr
# ,rqil
# 5. :m, grfrv, TfiS 3+frfr{ff, 1956 fiI tmr s *'ir6? effi1 qrF-rqt qr rfrrr
# +ri gv, R'rarr riTrcrq, q-fifr fir raro rr{, rrsfiq rtFa ,E s-rr rik sft}qrur
# sfiNq, fr rtf"id apt, ;r$ frFffi 6't 3164-3vser ffi t crda (ftfi'$q-htef{flrffi
# iefla *'sq fr *ma EFT;TI tt rm Eilqun ffifua qrd * Ert--qtfia t:
# i. q-;ffi 3flr tfr ssfirr fir Ti ryfr *. kdr sq-hqaf{+qrcrq *ienalqr
# {ff€r qm fq}arur il*T#t frr qnRdqmt w frffi&r+g *,r +tt 3Fq-r
# 5s{trr -5 f*ur ar(rrTil
# ii. (ESTFTrI8I , af ftrfr ffi eft tfr erfrEfr fr enfrfr afr ilrn or rs*f
# €EffRa a6t drn at ErEfuo rik arar qrffrt Ere rrffr ft dr
# iii. o.g6rrr&, rf fr*fi fr qarc ari ErA qtf,Fo q'r4fiIT kEfusqrcrq ry
# 3rrdrrr rik ,ttt6 {ifdfufr qftsdt/ffit rdRT fttrtffd Enn{S 3ik }ffirdt
# * r+w ffil
# iv. (-{S$Trr&, t$ frd {s Eq.q qr BqEffflrerq 3fifqrfr 3Trqtrr el-dRr s#rq-
# Frr{r trt enft Hrr<st rik frqn-fr&il fi r.+srr fr aE' etmm. qr6rt;Fzr/Errfrra,
# 3firF-*.r€ 1e;r*m4, 3{qrerq qftRrt qrs 6trnt
# v. {r"fiq q}FFfr *d*-r* (d sR}qnur fta, at tr* srd{itrm +.rffit *
# €Tq-rTrq Effic ait{ ndrqrt qtanfrfi 6,rdFH gs mrfr fi frq 3f,{a m'(fi
# gorc'rftt d€fla ar{fr Tfqra fr 5erre qH ilfi' fr mfrd rfr Gm, Efu
# TJrS EfutrfrnnBftft fi ss-sps rr.rerq RrqTr frfr-zozo * n;_+srr :r;a
# qffi fr BffiR ari +r rqrs qlznr
# vi. oq6ftn€r, il* friofr $rrq-Trtrq qr znn +htfua {ffi (sa trrqEfu[qrffr
# trF?fla) Efrqq, 2oz3 fr fttra srdrflat t 3rT{rR ssfr qnr ahnfr+'
# rTrd{fiHt/*rffif 6 trs{r+ nFn$T d6 1ur*r'y 6_qrrr dtr r.qrqa * fr('
# i\g-T=
# VII
# viiiq.*if* *-{re 3flT :d€?rrd qi {r'*rq {fliffi ('d riqFrdT qfurc luarrrwfi)
# rdrr ttr reqr{FT spa 6{ri d€r eff frrfiFn 6t, *' fu(' Teff 3Tqffia EF6#r
# 3r6KrrTil
# orjf 6 rd?r, 6rif fi rlqr qrrrar, etffiFrm'q1cFrfiveiltrfiq fi :rgatff *
# ;rdfdr+-rur, 6Tif fit r&qr &r;kn fr *trrr, r(r En6q;F-fi/6r{m-q W +-{i 3r,E
# *' Hrtrd fr {Eifrd sifdfrq,, qffif * sefr frqtfra amcs ritr qffi HreT
# {B-fI 3itr {E{rq q}f,Ffr 3qutrrn :it* yRrerur qftw-{ ((rdr€rfuTr€ry, fr 3r{Fff
# qFt, T$ fr,cdT qarr {trfir qvraa fuqr arqrenl
# (GrS$Trr&, nt m 1-trT (sq fteafddlqrerq :iefla) Bfrqff, 2023 +
# qrdtrrdt + r"+urr {ffi/flelwr dTffiq +t aoa t ra 3ilr;Tr +iltmo d-rET
# aFt;r ((rmi(')/fr{fr ry +trnt aq efi 3rrdQqfi d, dena yqfra trfr{rfft
# * srdtrdt * :1
# "+sr srq$ trqrfr(rlfut fiI :rryfrf, qr ri?ifuf, qr qfirqffia
# qtnt
# ix. (mS*TrrA, tr$ ffi q-difr sif{ ,iEima €iEfu+, qfirvd * Mt 3i1-{
# Efut + :rg*m giffi ir#Tr fiT qd;r strnt
# x. (6SI$:Tr€I, tr$ fufr {s frrrf,q fi {rqrq :iTelrrrd ttfrar ffi
# (w3nfuiltq'q.) tdr{r "Trft Erffis. eTr{drq ttfrer fr errrr +rnr
# xi. o455sr€r, r$ frffi qi $qildfr*. t+' 3ilw A;Bd ((-trS) 3{fudr$ w t
# Ir;Tr;TT ilrn, 3Tqfr 6rit frr q6,qFT 6.{fr 6trft 3i1-r rf,h *Bs Ft{ 6t fdfrffi
# Ff-fi{ 6 sqfrs ifi'Grr ilqr 3if{ z16 gfrR-{d mral Etm fu A;Bd r+t{ ('ffi
# dtd fr rffi'la 6t 3it-t uqet *-erqfrH qi $qfrKrrnl
# TB\=tX
# (ffituqt{ ffirs)
# q.d €frq, 8lTq;r T1gdFR
# wsTrq: +9 1 11 2401 5038
# qrltlfi,
# e{rGI Tr{fiR ry,ftf {tE, a€ frre 110002
# gft sdfta'
# 1. Trfrq, q:a RI&Tr rik lrrarrar BaTrrr, RIHT TiflFrq, a$ frrfita
# 2. HBE, fuqtfiqrffi q-drd rlfrrr, {615{?16 aw-r ml', n$ EEfr - 11ooo2
# 3. Trtrq sfra, 3rfu6T eTrrdrq il*#fir firmr qftw-{ t(BTr{Hfe$, AFrFr dtmr
# rrrrt, T{i.T Td, rr$ E,."fr-t 10070
# 4. F,*r+-, ('trSrfurr&, fr rrffi HFt, r$ ftrfrr
# 5. Erd qilf,r s-rqtcrq, ?n€fr aTrf;r, r$ Ed-110001
# 6. r5r€rfue, eTrdrq fuaf*c_+rau +iq, q.3[rt.{. 6rr[, 16, 6tenr Hrrl', ag ffudr
# - 110002
# 7. q-* Ftnr+ (wnsa; 3lk +E ffiBf, r?Ekrt Rrffir fue{rrr, ?ngfr ar+a, a$
# frffi t grd,tttr t m SqffiTr€r'€ Sffirt +t r.qr< R'rqTr he{rrr fr aqsr{c
# tR Sffi 3Tfuq-fiTr fr) r6fe1a +.ri * frq 3{rq?T6'frftr snt *tr
# 8. Hmdrq ft'ren Ei* il ffi *rfuqt
# 9. rn5 mgalnfuq+ar TFrSeTt
# C
# (-dfr fura1
# 3ftR Trfdq, aTr{.[ Trrdrn
# WeTrq: +91 11 24014923
#
#
# m-flmr-l t�
# � l@fq'{,. ��ft
# 'ffftTct
# Prof. Manish R. Joshi
# Secretary
# F.1 o.l-12/2025(1C)
# NOTICE 7��
# Jil\J"Jl�cnT
# � 11-6,--rct-i.--.-q
# fcl:tcll4WE14 �(GR' 3WTT1T
# University Grants Commission
# (�mr �. 11mr �)
# (Ministry of Education, Govt. of Indio)
# 9 tmf, 1947/301h Dcccmhcr, 2025
# Subject: l'articipation of llighcr Education Institutions (II Els) in the Erasmus+ Programme
# qi;')�Qt/�,
# All I lighcr Education Institutions (I IEls) arc hereby informed about the Erasmus+ Programme, which is the
# llngshir progr:in11ne of the Eurorean Union aimed at strengthening international cooperation in higher education.
# The progrnmmc offers structured orrortunities for student and academic mobility, capacity building, and
# institutional p:irtncrships with universities in EU member states and pnrtner countries, including lndi:a. Erasmus+
# annually :in11ou111ces a "Call for Proposals" during November-December, offering individual scholarships and
# institution:.il collnborntion opportunities through following four programmes (i11for111atio11 brochure al/ached):
# (i) lntcrn:1tio11:1I Credit Mobility (ICM) surporting short and long-term mobility of students and s'laff.
# (ii) Erasmus l\1undus .Joint Masters (EM.IM) fully funded one or two-year master's programmes delivered by
# Erns111us I universities consortia.
# (iii)Capacity Building for Higher Education (CBIIE) supporting 2-3 year projects focused on curriculum
# dcvclor111c11t. institutional reform, and governance improvement.
# (iv).Jc:111 l\lo11111et Acti\'itics (JM,\) promoting leaching and research on European Union studies.
# The last daces for submission of proposals under these programs fall in early/mid-February 2026. For
# coordirrntiontrurther informntion underthe Erasmus+ Programme. an Erasmu�+ National Focal Point (ENFP) has
# been designated. dctai Is of which arc as under:
# Shri Rajccv Kumar Sinha, Under Secretary (ICC), Dept. of Higher Education, Ministry of
# Education, Government of India, New Delhi (Email: iccell.edu@nic.in, rajecvk.sinha@nic.irr)
# All HEls arc encouraged to actively explore participation in Erasmus+ initiatives by strengthening collaborations
# with Eurorean higher educntion institutions. promoting mobility of students and academic stafT, andl submitting
# quality proposals, under relevant Erasmus+ actions. Such participation will contribute to the internationalisation of
# Indian higher ed11catio11 and enhancement of academic quality and global exposure .
# An "Online Information Session" on potential opportunities under the Erasmus+ Programme is proposed to be
# organised in early January 2026. in collaboration with the Erasmus+ team and the details will be shared by the
# designated ENFP soon. Institutions arc requested to disseminate this information widely within institutions and take
# suitable steps to llcveragc the opportunities available under Erasmus+ Programme .
# lTTG{,
# To.
# The VCs of Central and Deemed to be Universities
# �1� � lf11i, ;i-t �110002 I Bohodur Shah Zafar Marg, New Delhi-110002
# � (Ph.): Ol l-23236288/23239337 I lfPfi � (i�) (E-mail): secy.ugc@nitin
#
#
#
#
# Erasmus+ Programme
# International credit mobility
#
#
# What is Erasmus+?
# For over 30 years, Europe has funded the Erasmus programme, which has enabled over four million European students to
# study, train, and gain experience abroad.
# Erasmus+ recognises the importance of opening up these opportunities,  funding  exchange of students, acad emics , id ea s
# and good practice between  Programme countries1 and Partner countries2 throughout the world.
# In the framew ork of the new programme 2021 -2027, the international activities will cover  Higher E ducation (HE),
# Vocational Education and T raining (VET), Youth and Sport .
# What is  an International credit mobility  project ?
# International credit mobility (ICM)  supports the mobility of individuals in higher education institutions (HEIs), b etween
# Programme countries and Partner countries. Through ICM, European HEIs can set up mobility agreements with partners
# around the world3 to send and receive st udents and staff.
# What does a n ICM project do?
# The activities supported in ICM are:
# Student mobility : can be carried out in any study field and cycle  (short cycle/bachelor/master/doctoral) , and is open to
# recent graduates.  The physical mobility can last from 2 to 12 months  or between 5 and 30 days  if part of blended
# mobility4. Student mobility can take the form of:
#  A study period  abroad at a partner HEI ,
#  A traineeship  (work placement, internship) abroad in an enterprise, a research institute, a laboratory, an
# organisation or any other relevant workplace.
# The two types of student mobility could be combined , if the total duration of the mobility period does not  exceed th e
# maximum of 12 months per study cycle.
# Staff mobility:  can be carried out by any type of higher education staff or by invited staff from outside the HEIs. The
# mobility period can last from 5 days to 2 months . It can take the form of:
#  A teaching period  for academic staff and for invited staff from non -academic organisations to teach at a
# partner HEI abroad,
#  A training period  for teaching and non -teaching staff in the form of training events abroad (excluding
# conferences), job shadowing, observation periods and/or training at a partner HEI.
# A staff mobility period abroad can combine teaching and training activities. Any teachi ng or training period abroad may b e
# carried out as a blended mobility.
#
# 1 EU member states and third countries associated to the Programme .
# 2 Third countries not a ssociated to the Programme .
# 3 With the exception of Andorra, Faroe Islands, Monaco, San Marino, Switzerland, Vatican City State  and the United Kingdom.
# 4 Blended mobility is a combination of physical mobility with a virtual component facilitating a collaborative online learning exchange
# and teamwork.
#
#  How is it funded?
# ...
# Euros/ month of study (max. 24 months) with a max. amount of  2 016 000 Euros  per grant .
# o In addition, consortia may apply for additional scholarships  for targeted regions  worldwide.
# o Contribution to cover  special needs of the students : max. 120 000 Euro per project .
#  Type of degree awarded:  either  a joint degree (recommended)  or multiple degrees.
# Who can apply and take part in EMJM ? How?
# Taking part as an organisation:
#  EMJMs are open to any public or private organisation l ocated in a  Programme Country or Partner Country:
# o Higher Education Institutions (HEIs)
# o Non-academic partners (enterprises, non -profit organ isations, NGOs, foundations, etc. )
#  Any eligible HEI established in a  Programme Country or Partner Country  can submit an application
#  Associated partners (optional): contribute indirectly to the implementation of specific task s/activities. For
# contractual management issues, they are not cons idered as part of the partners of the EMJM partnership.
#
#  Funding opportunities for 2021 -2027 and information on how to apply are announced on the European
# Commission’s Funding & Tender Opportunities portal : https://ec.europa.eu/info/funding -
# tenders/opportunities/portal/screen/home
# Taking part as a  student :
#  EMJMs are open to students from all over the world .
#  Among the rec ruited students, the  highest -ranked applicants  benefit from a scholarship depending on the numb er
# of scholarships available.
#  The scholarship is awarded for a minimum of 12 months and up to 24 months depending on the master
# programme duration  (60/90/120 ECTS credits) .
#  The scholarship covers travel, visa, installation and subsistence costs and is calculated on the basis of a mo nth ly
# unit cost of 1400 Euros/month  which corresponds to a maximum scholarship amount of 33 600 Euros  (24
# months) .
#  Additional financial support is available for  students with individual  needs  depending on  the level of
# disability/ support needed with a maximum contribution of 60  000 Euros.
#
#  Applications have to be submitted directly to the Erasmus Mundus Joint Master Prog rammes which can be
# found in the EMJM catalogue: https://www.eacea.ec.europa.eu/scholarships/emjmd -catalogue_en
# More information
# Detailed information on the criteria and funding  rules :  Erasmus+ Programme Guide
# Information on how to apply to annual calls for proposals  is provided  on the European Commission’s Funding &
# Tender Opportunities portal : https://ec.europa.eu/info/funding -tenders/opportunities/portal/screen/home
# Erasmus Mundus  mailbo x: EACEA -EPLUS -ERASMUS -MUNDUS@ec.europa.eu
#
#
#
#
#
#
# Erasmus+ Programme
# Capacity -building in the field of higher education  (CBHE )
#
# What is Erasmus+?
# For over 30 years, Europe has funded the Erasmus programme, which has enabled over four million European students to
# study, train, and gain experience abroad.
# Erasmus+ recognises the importance of opening up these opportunities,  funding  the exchange of students, academics, idea s
# and good practice between  organisations in Programme countries1 and Partner countries2 throughout the world.
# In the framew ork of the new programme 2021 -2027, the international activities will cover  Higher E ducation (HE),
# Vocational Education and T raining (VET), Youth and Sport .
# What is  a CBHE project ?
# A Capacity Building for Higher Education  project operates as a multilateral partnership between institutions active in
# the higher education field from Programme Countries and Partner Countries. Projects  support the relevance, quality,
# modernisation and acces sibility of higher education, to make it a driver for sustainable social and economic development.
# All projects are required to pursue and observe the guiding principles of the action: inclusiveness , innovation, imp act and
# sustainability.
# What does a  CBHE project do?
# CBHE projects can carry out a range of activities  focused on Partner  Countries :
#  Develop, test and adapt curricula, in terms of relevant and innovative content and through the teaching and
# learning methods used;
#  Support university -enterprise cooperation;
#  Work on upskilling and professionali sation of academic and administrative staff;
#  Reform of the governance and management systems and structures at national, regional or institutional level ;
#  Foster the internationalisation of HEIs and their cap acity to network effectively in research, scientific and
# technological innovation;
#  Support the introduction of Bologna -type reforms at institutional, national or regional level;
#  Develop and implement new approaches and tools for policy making and monitorin g
#
# Three  types of project s:
# 1. FOSTERING ACCESS TO COOPERATION IN HIGHER EDUCATION :
# These smaller scope projects are focused on higher education institutions. This project type is new and designed to cater for
# newcomers to the programme, less involved countries/regions, and for disadvantaged target  groups. Project budget
# between EUR 200 0 00 and EUR 400 000 , 2-3 years.
#
# 1 EU Member States and third countries associated to the programme.
# 2 Third countries not associated to the programme .
#
# 2. PARTNERSHIPS FOR TRANSFORMATION  IN HIGHER EDUCATION :
# These are also focused on higher education institutions, but designed to have a large r and wider impact on innovation,
# university/business relations and institutional gove rnance.
# Project budget between EUR 400 000 and EUR 800 000 , 2-3 years .
# 3. STRUCTURAL REFORM PROJECTS :
# These projects focus on the macro level of policy reforms  required to foster internationalisation . Besides higher ed ucation
# institutions  they will also requ ire the i nvolvement of education authorities and /or ministries.  Project budget b etween EUR
# 800 000 and EUR 1 000  000, 3-4 years.
# Who can apply and take part in Capacity -building in Higher Education ? How?
# Taking part as an organisation:
# Participation in CBHE projects is open to a range of stakeholders  in the higher education sector:
# Higher Education Institutions (HEIs)
#  HEIs, association s or organisation s of HEIs, as well as legally recognised national or international rector, teacher or
# student organisati ons;
#  Bodies in charge of higher education (councils, agencies) and national authorities (ministries, departments of
# higher education ) in partner countries for those projects supporting reform processes at national/regional level;
#  Vectors of change in the education system ( university managers, international departments, deans, quality
# agencies , etc.);
#  Organisations and/or associations active in the labour market or in the fields of education, training or youth in
# partner countries.
# Project partnerships
# All projects must be based on a partnership of organisations from Programme Countries and from Partner Countries :
# - Minimum 4 organisations
# - Minimum 1 HEI from 2 Programme Countries and 2 HEIs from one or more Partner Countries.
# - The number of organisations from P rogramme countries should not be higher than the number of
# organisations from Partner countries
# Who can apply?
#  HEIs, association s or organisation s of HEIs, as well as legally recognised national or international rector, teacher or
# student organisations, es tablished in a Programme Country or in one of the eligible Partner Countries3. The
# applicant institution applies on behalf of all participating organisations involved in the project.
# How to apply
#  Funding opportunities for 2021 -2027 and information on how to apply are announced on the
# European Commission’s Funding & Tender Opportunities portal:
# https://ec.euro pa.eu/info/funding -tenders/opportunities/portal/screen/home
# What is new in 2021 -2027?
#  New structure for projects – three categories based on size and scope.
# More information
# Detailed information on the criteria and funding rules :  Erasmus+ Programme Guide
#
#
# 3 Countrie s belonging to the following re gions: Western Balkans, Neighbourhood East, South  Mediterranean, Russian Federation, Asia, Ce ntral Asia,
# Middle East, Pacific, Sub -Saharan Africa, Latin Ame rica, Caribbe an . Participation is not possible from high -income countri e s in Asia, Middle East and the
# Pacific. For more  information  about these re gions : see the Programme guide.
#
#
#
# Erasmus+ Programme
# Jean Monnet Action for higher education
#
# Stimulating teaching and research on the European Union and foster dialogue
# between academics and decision- makers  in the EU and around the world
#
# What is Erasmus+?
# For over 30 years, Europe has funded the Erasmus programme, which has enabled over four million European
# students to study, train, and gain experience abroad.
# Erasmus+ recognises the importance of opening up these opportunities, funding exchange of students, academics, ideas and good practice s between organisations in Programme Countries
# 1 and Partner C ountries2 throughout the
# world.
# These global  activities cover Higher Education (HE), Vocational Education a nd Training (VET), Youth and Sport.
# What  are Jean Monnet Actions?
# The Jean Monnet Actions  for higher education aim at promoting excellence worldwide  in teaching and
# research  in the field of European Union studies . These Actions also aim at fostering dialogue between the
# academic world and policy -makers , in particular with the aim of enhancing governance of EU policies.
# ‘European Union studies ’ means  the study of Europe in its entirety , with particular emphasis on the EU
# dimension, from an internal but also from a global perspective .
# European Union studies cover the role of the EU in a globalised world and in promoting active European citizenship and dialogue between people and cultures.
# Jean Monnet is expected to bring positive and long-l asting effects to the participants  involved, to the
# promoting organisations,  and to the policy systems within which they are framed.
# Which Actions are supported?
# Teaching and research activities:
# New introductory or advanced teaching programmes or courses  designed to be embedded in the
# official curriculum of a higher education institution.
# • A Jean Monnet Module  is a short teaching programme or course in the field of European Union Studies
# at a higher education institute. Each Module  lasts three  years with  a minimum duration of 40 teaching
# hours per academic year. Modules may concentrate on one particular discipline in European studies or be multidisciplinary in approach.
# • A Jean Monnet Chair  is a teaching post with a specialisation in European Union Studies f or university
# professors  for duration  of three  years . The position is held by only one professor, who provides the
#
# 1 EU member states and third countries associated to the Programme.
# 2 Third countries not associated to the Programme.
# minimum of 90 teaching hours per academic year. The Chair may also have a team to support and
# enhance the activities of the Chair, including the provision of additional teaching hours.
# • Centre of Excellence is a hub or focal point of competence and knowledge on European Union subjects
# with project duration of  three  years.  The Centre has a major role in reaching out to students from
# faculties not normally dealing with European Union issues as well as to policy makers, civil servants, organised civil society and the general public. The requirement to hold a Chair in order to set up a Centre
# of Excellence is removed.
# Jean Monnet policy debate
# Large thematic networks in Higher Education  (one network on internal EU issues and one network on foreign
# policy issues addressing one specific priority will be supported each year) will have as primary objective to collect, share and discuss among the partners research findings, content of courses and experiences, products (studies, articles, etc.).  Each network will establish a tool allowing the partners to share their academic works and run peer
# review exercises, also commenting on the posted documents.
# Who can apply and take part in Jean Monnet actions? How?
# Higher education institutions, organisations and associations around the world are eligible to apply for Jean Monnet actions . HEIs established in Programme Countries  must hold a valid Erasmus Charter for Higher Education
# (ECHE). An ECHE is not required for  participating HEIs in Partner Countries .
# More information
# Detailed information on the criteria and funding rules :  Erasmus+ Programme Guide
# Information on how to apply to annual calls for proposals  is provided on the European Commission’s
# Funding & Tender Opportunities portal: https://ec.europa.eu/info/funding -tenders/opportunities/portal/screen/home
# Jean Monnet m ailbox: EACEA -AJM@ec.europa.eu
#
#
#
#
# � � "{. iiITTft
# �
# Prof. Manish R. Joshi
# Secretary ��
# <tt1d.:itF.lcti � �i'!ii�cfif
# � ...... J.t�...+��--q
# mc1fch.UW-4 � �
# University Grants Commission
# (��� .�� )
# IMinislry of Education, Govt. of Indio)
# 19 b, 194s / 9 � 2026
# �, �ffi3m:T�cfil3fc:rncf��tfcn-1%ilfr��
# �afa",41<>14�;m:m.m ��cf:i'l"ar�t�� �, m� �m� � * � � 6 m � m=m � .!!_,:,1�fl� �, 1956 c);-� f%ilfr
# �mc);-im!"�tl
# e; 1 <>1 if4i, .!!_-:,1� .ffl * t.<na, R 3il<rr t fcn" � � 1 ,:,1�f1"1 � * � c); fa q fl c1 �
# ���61 �finafac;_41<>1.Q1/�3TT��cf:;'r-���cTI J-lla-�c1I �� m�tf�fi)-ffi� ,(�,,tdll,( ��mc);-imr��I
# $-H�Q, ��t �tfcn"cr:3WfmTTc);-1mr�3fi�RmrAAt� �
# J-llcr4c11 � fcl�afclc;_�l<>i�;m:m.m c);-�-� � � c);- iJR" � ;,tla1c:f,lfl c);-im!"
# .!!_"11.ffi cf:i'l" chi-Hl$C:: www.ugc.ac.in �I
# � 3rc'ITTIT, � � fa�a fa c;_4 I <>14 /ml :q_-:,1� fl� � cf> 3 c--c-i � a1 � � c:f,I � sfid-1
# ���t, cTI'3'a�: ugcampc@gmail.com c),1Tit.,�� .!!_,:,t�fl� c);-l.<na,R�°c11fcF;
# � � c);- rul <>1 I Cfi 3TT@ c:f,l�a 1$ cf:i'I" al"� I � ;,t la1 c:f,lfl � 1mr � � 'll1!' fifcf;- cfiT
# �:
# https://drive.google.com/drive/folders/13 lbOT7cyPPF6p4KLUgST2VE8sc8nbAp?usp =driv
# e link
# �iim; � lfllf, � M'-110002 I Bohodur Shah Zafar Marg, New Delhi-110002
# � (Ph.): 0ll-23236288/23239337 I � Wf (1�) (E-mail): secy.ugc@nic.in
# 1!9-IQR � ��"{. *�ft •
# Prof. Manish R. Joshi
# Secretary
# F.No. 7-3/2012(AMPC)�wra 7r-1>. -
# �1'5il�q)T
# � J.t �, ri-l '"'
# F\�i.i�t.0(!1£1 � �
# University Grants Commission
# (�ml �. \tffif �)
# (Ministry of Educotion, Govt. of Indio)
# 19 b, 1948/ 09th April, 2026
# It is hereby brought to the notice of students, parents and the general Public that degree
# can be awarded only by Universities/Institution which are established under a State Act,
# or Central Act or Provincial Act or institution, empowered to confer or grant degrees as
# per UGC Act, 1956.
# However, it has come to the notice of UGC that a number of institutions are offering
# degrees in contrary to the provision of the UGC Act. Degrees awarded by such
# universities/institutions shall neither be recognized nor valid for higher education and
# employment purposes.
# Hence, all concerned are requested to check the UGC website: www.ugc. gov.io for
# information about recognized universities/institutions as well as fake institutions before
# taking admission in any institution for higher education. Further, if any
# university/institution is offering academic programmes in contravention of the UGC Act,
# the same may also be brought to the notice of UGC via email to ugcampc@gmail.com so
# that appropriate action can be taken against such institutions.
# For more information, please see the following link:
# https://drive.google.com/drive/fold.er.s.l13 lbOT7cyPPF6p4KLUqST2VE8sc8nbAJilu
# sp=drive link
# �� � lf11T, � �-110002 I Bohodur Shah Zafar Marg, New Delhi-110002
# � (Ph.): Oll-23236288/23239337 I � wr (t�) (E-mail): secy.ugc@nic.in

# %% [markdown]
# # Remove Extra Spaces

# %%
def remove_whitespace(all_text):
  return  " ".join(all_text.split())

# %% [markdown]
# # Store Cleaned Text & Print

# %%
lower_case_sentence = remove_whitespace(all_text)
print(lower_case_sentence)
# Out:
# &hQqRgr@ a3qTq wlMl University Grants Commission (f§RW tvrqq, vm nrr) (Ministry of Education, Govt. of India) #TglHTF asl wt, Hf eM-110002 Bahodur Shah Zafar Marg, New Delhi-110002 Ph., 01 1-23236288/23239337 Fox , 01 1-2323 8858 E-mail , secy.ugc@nic.inrn-fqgn fq3Ml ThT Secretary D.O.No. 2-25/2024(CPP-II)(C.144198) 2 aTV, 1947/ 22"d January, 2026 Subject: Free of cost verification of the genuineness of the educational certificates. XTRWRTHdTTr/HORn This is in continuation of the UGC communication dated 30th May 2024, regarding the verification of educational certificates of newly recruited Assistant Section OfFicers (DRASOs) through the Combined Graduate Level Examination (CGLE) conducted by the Staff Selection Commission (SSC). A copy of the earlier communication is attached for reference. It is emphasized once again that verification of educational qualifications, in addition to other prescribed verifications, is a prerequisite for confirmation of the appointed officers in the Government service. In the interest of the Government, it is necessary to ensure the genuineness of candidates. Therefore, it should be the obligation of each educational institute, including private/deemed universities, to conduct this verification free of cost. Therefore, all the Central/State/Deemed/Private Universities and other Higher Education Institutions are hereby requested to undertake free of cost verification of the genuineness of the educational certificates for all recruitments to Central Government posts, irrespective of recruiting agency, whenever any Ministry/Department or any other Central Government organization makes a request to this effect. TIKI, 8TaaT, h:rb (qdbIRTa;T) +TT +, n+fBqafB@nHa + TnTfRI T18ft#61faqql,la + ylqIJI 1 HIV ’i# m llm in#1 VIVId qf+q r. ;it9ft undfqqqfiaTml ayn vram University Grants Commission T3r4T LiII]]. HIll A J+rJ (Ministry of Education. Govt. of !rldio) Prof. Manish R. Joshi Secretary D.O.No.2-25/2024(CPP-II) 30th May, 2024/ 09 Ma, 1946 Subject: Free of cost verification of genuineness of the educational certificates. 3n€wh4 xdeTr/HdeT. As you are aware, the verification of Educational Qualification is a pre-requisite for confirmation of the appointed officers in the Government service. It is necessary in the interest of the Government to ensure the genuineness of the candidates, and hence, it should be the obligation of each educational institute, including private/deemed universities. to do this verification free of cost In this regard, it is stated that there have been several instances wherein educational institutions demanded fees for the verification of educational certificates of newly recruited Assistant Section Officers (DRASOs) through the Combined Graduate Level Examination (CGLE) conducted by the Staff Selection Commission (SSC) The Higher Education institutions are requested to verify the genuineness of the educational certificates of newly recruited ASOs in SSC free of cost whenever any Ministry/Department makes a request to that effect to undertake such verification TrTI, (xRv ahH) tH R, nfl fBq4fBana=# iT @;faI III& d$1fac,dIdO + yidIJ 1 FV3TR Wr qm. n mt-1 t ti'III: Bahodur Shoh Zctor Morg Ne',v Delhi-110002 TITH (Ph ): ai 1-23236288/23239337 wn pr ::+1) {E-lnail) secy.ugc:10nic.,il ffl,!-�� � � �. iiITTft � Prof. Manish R. Joshi Secretary F.No. 1-47 /2026(ARC)�� 7C� /"� .........,; '311'511� cfil � ....... J.f $-� c-fi-....-,.q mc1i4sUW.f � 3TI1.fT1T University Grants Commission (�rur �. 'qffif �) (Ministry of Education, Govt. of India) 19 b / 1948 / 09 April, 2026 Subject: Strict Compliance with UGC Regulations on Safety and Security of Students in Higher Educational Institutions (HEis) -reg. 311G�oflq l-li?JGql/�, The University Grants Commission (UGC) is committed to ensuring the safety and security of students. To ascertain the same, UGC has notified and issued various regulations and guidelines from time to time for ensuring the safety, security� and well-being of students in Hl ...

# %% [markdown]
# # Tokenizer

# %%
from nltk import word_tokenize

tokenized_sentences = word_tokenize(lower_case_sentence)
print(tokenized_sentences)
# Out:
# ['&', 'hQqRgr', '@', 'a3qTq', 'wlMl', 'University', 'Grants', 'Commission', '(', 'f§RW', 'tvrqq', ',', 'vm', 'nrr', ')', '(', 'Ministry', 'of', 'Education', ',', 'Govt', '.', 'of', 'India', ')', '#', 'TglHTF', 'asl', 'wt', ',', 'Hf', 'eM-110002', 'Bahodur', 'Shah', 'Zafar', 'Marg', ',', 'New', 'Delhi-110002', 'Ph.', ',', '01', '1-23236288/23239337', 'Fox', ',', '01', '1-2323', '8858', 'E-mail', ',', 'secy.ugc', '@', 'nic.inrn-fqgn', 'fq3Ml', 'ThT', 'Secretary', 'D.O.No', '.', '2-25/2024', '(', 'CPP-II', ')', '(', 'C.144198', ')', '2', 'aTV', ',', '1947/', '22', "''", 'd', 'January', ',', '2026', 'Subject', ':', 'Free', 'of', 'cost', 'verification', 'of', 'the', 'genuineness', 'of', 'the', 'educational', 'certificates', '.', 'XTRWRTHdTTr/HORn', 'This', 'is', 'in', 'continuation', 'of', 'the', 'UGC', 'communication', 'dated', '30th', 'May', '2024', ',', 'regarding', 'the', 'verification', 'of', 'educational', 'certificates', 'of', 'newly', 'recruited', 'Assistant', 'Section', 'OfFicers', '(', 'DRASOs', ')', 'through', 'the', 'Combined', 'Graduate', 'Level', 'Examination', '(', 'CGLE', ')', 'conducted', 'by', 'the', 'Staff', 'Selection', 'Commission', '(', 'SSC', ')', '.', 'A', 'copy', 'of', 'the', 'earlier', 'communication', 'is', 'attached', 'for', 'reference', '.', 'It', 'is', 'emphasized', 'once', 'again', 'that', 'verification', 'of', 'educational', 'qualifications', ',', 'in', 'addition', 'to', 'other', 'prescribed', 'verifications', ',', 'is', 'a', 'prerequisite', 'for', 'confirmation', 'of', 'the', 'appointed', 'officers', 'in', 'the', 'Government', 'service', '.', 'In', 'the', 'interest', 'of', 'the', 'Government', ',', 'it', 'is', 'necessary', 'to', 'ensure', 'the', 'genuineness', 'of', 'candidates', '.', 'Therefore', ',', 'it', 'should', 'be', 'the', 'obligation', 'of', 'each', 'educational', 'institute', ',', 'including', 'private/deemed', 'universities', ',', 'to', 'conduct', 'this', 'verification', 'free', 'of', 'cost', '.', 'Therefore', ',', 'all', 'the', 'Central/State/Deemed/Private', 'Universities', 'and', 'other', 'Higher', 'Education', 'Institutions', 'are', 'hereby', 'requested', 'to', 'undertake', 'free', 'of', 'cost', 'verification', 'of', 'the', 'genuineness', 'of', 'the', 'educational', 'certificates', 'for', 'all', 'recruitments', 'to', 'Central', 'Government', 'posts', ',', 'irrespective', 'of', 'recruiting', 'agency', ',', 'whenever', 'any', 'Ministry/Department', 'or', 'any', 'other', 'Central', 'Government', 'organization', 'makes', 'a', 'request', 'to', 'this', 'effect', '.', 'TIKI', ',', '8TaaT', ',', 'h', ':', 'rb', '(', 'qdbIRTa', ';', 'T', ')', '+TT', '+', ',', 'n+fBqafB', '@', 'nHa', '+', 'TnTfRI', 'T18ft', '#', '61faqql', ',', 'la', '+', 'ylqIJI', '1', 'HIV', '’', 'i', '#', 'm', 'llm', 'in', '#', '1', 'VIVId', 'qf+q', 'r.', ';', 'it9ft', 'undfqqqfiaTml', 'ayn', 'vram', 'University', 'Grants', 'Commission', 'T3r4T', 'LiII', ']', ']', '.', 'HIll', 'A', 'J+rJ', '(', 'Ministry', 'of', 'Education', '.', 'Govt', '.', 'of', '!', 'rldio', ')', 'Prof.', 'Manish', 'R.', 'Joshi', 'Secretary', 'D.O.No.2-25/2024', '(', 'CPP-II', ')', '30th', 'May', ',', '2024/', '09', 'Ma', ',', '1946', 'Subject', ':', 'Free', 'of', 'cost', 'verification', 'of', 'genuineness', 'of', 'the', 'educational', 'certificates', '.', '3n€wh4', 'xdeTr/HdeT', '.', 'As', 'you', 'are', 'aware', ',', 'the', 'verification', 'of', 'Educational', 'Qualification', 'is', 'a', 'pre-requisite', 'for', 'confirmation', 'of', 'the', 'appointed', 'officers', 'in', 'the', 'Government', 'service', '.', 'It', 'is', 'necessary', 'in', 'the', 'interest', 'of', 'the', 'Government', 'to', 'ensure', 'the', 'genuineness', 'of', 'the', 'candidates', ',', 'and', 'hence', ',', 'it', 'should', 'be', 'the', 'obligation', 'of', 'each', 'educational', 'institute', ',', 'including', 'private/deemed', 'universities', '.', 'to', 'do', 'this', 'verification', 'free', 'of', 'cost', 'In', 'this', 'regard', ',', 'it', 'is', 'stated', 'that', 'there', 'have', 'been', 'se ...

# %% [markdown]
# # Lower Case

# %%
text_lower = lower_case_sentence.lower()
print(text_lower)
# Out:
# &hqqrgr@ a3qtq wlml university grants commission (f§rw tvrqq, vm nrr) (ministry of education, govt. of india) #tglhtf asl wt, hf em-110002 bahodur shah zafar marg, new delhi-110002 ph., 01 1-23236288/23239337 fox , 01 1-2323 8858 e-mail , secy.ugc@nic.inrn-fqgn fq3ml tht secretary d.o.no. 2-25/2024(cpp-ii)(c.144198) 2 atv, 1947/ 22"d january, 2026 subject: free of cost verification of the genuineness of the educational certificates. xtrwrthdttr/horn this is in continuation of the ugc communication dated 30th may 2024, regarding the verification of educational certificates of newly recruited assistant section officers (drasos) through the combined graduate level examination (cgle) conducted by the staff selection commission (ssc). a copy of the earlier communication is attached for reference. it is emphasized once again that verification of educational qualifications, in addition to other prescribed verifications, is a prerequisite for confirmation of the appointed officers in the government service. in the interest of the government, it is necessary to ensure the genuineness of candidates. therefore, it should be the obligation of each educational institute, including private/deemed universities, to conduct this verification free of cost. therefore, all the central/state/deemed/private universities and other higher education institutions are hereby requested to undertake free of cost verification of the genuineness of the educational certificates for all recruitments to central government posts, irrespective of recruiting agency, whenever any ministry/department or any other central government organization makes a request to this effect. tiki, 8taat, h:rb (qdbirta;t) +tt +, n+fbqafb@nha + tntfri t18ft#61faqql,la + ylqiji 1 hiv ’i# m llm in#1 vivid qf+q r. ;it9ft undfqqqfiatml ayn vram university grants commission t3r4t liii]]. hill a j+rj (ministry of education. govt. of !rldio) prof. manish r. joshi secretary d.o.no.2-25/2024(cpp-ii) 30th may, 2024/ 09 ma, 1946 subject: free of cost verification of genuineness of the educational certificates. 3n€wh4 xdetr/hdet. as you are aware, the verification of educational qualification is a pre-requisite for confirmation of the appointed officers in the government service. it is necessary in the interest of the government to ensure the genuineness of the candidates, and hence, it should be the obligation of each educational institute, including private/deemed universities. to do this verification free of cost in this regard, it is stated that there have been several instances wherein educational institutions demanded fees for the verification of educational certificates of newly recruited assistant section officers (drasos) through the combined graduate level examination (cgle) conducted by the staff selection commission (ssc) the higher education institutions are requested to verify the genuineness of the educational certificates of newly recruited asos in ssc free of cost whenever any ministry/department makes a request to that effect to undertake such verification trti, (xrv ahh) th r, nfl fbq4fbana=# it @;fai iii& d$1fac,dido + yidij 1 fv3tr wr qm. n mt-1 t ti'iii: bahodur shoh zctor morg ne',v delhi-110002 tith (ph ): ai 1-23236288/23239337 wn pr ::+1) {e-lnail) secy.ugc:10nic.,il ffl,!-�� � � �. iiittft � prof. manish r. joshi secretary f.no. 1-47 /2026(arc)�� 7c� /"� .........,; '311'511� cfil � ....... j.f $-� c-fi-....-,.q mc1i4suw.f � 3ti1.ft1t university grants commission (�rur �. 'qffif �) (ministry of education, govt. of india) 19 b / 1948 / 09 april, 2026 subject: strict compliance with ugc regulations on safety and security of students in higher educational institutions (heis) -reg. 311g�oflq l-li?jgql/�, the university grants commission (ugc) is committed to ensuring the safety and security of students. to ascertain the same, ugc has notified and issued various regulations and guidelines from time to time for ensuring the safety, security� and well-being of students in hl ...

# %% [markdown]
# # Punctuation

# %%
import string
text_no_punct = text_lower.translate(str.maketrans('', '', string.punctuation))
print(text_no_punct)
# Out:
# hqqrgr a3qtq wlml university grants commission f§rw tvrqq vm nrr ministry of education govt of india tglhtf asl wt hf em110002 bahodur shah zafar marg new delhi110002 ph 01 12323628823239337 fox  01 12323 8858 email  secyugcnicinrnfqgn fq3ml tht secretary dono 2252024cppiic144198 2 atv 1947 22d january 2026 subject free of cost verification of the genuineness of the educational certificates xtrwrthdttrhorn this is in continuation of the ugc communication dated 30th may 2024 regarding the verification of educational certificates of newly recruited assistant section officers drasos through the combined graduate level examination cgle conducted by the staff selection commission ssc a copy of the earlier communication is attached for reference it is emphasized once again that verification of educational qualifications in addition to other prescribed verifications is a prerequisite for confirmation of the appointed officers in the government service in the interest of the government it is necessary to ensure the genuineness of candidates therefore it should be the obligation of each educational institute including privatedeemed universities to conduct this verification free of cost therefore all the centralstatedeemedprivate universities and other higher education institutions are hereby requested to undertake free of cost verification of the genuineness of the educational certificates for all recruitments to central government posts irrespective of recruiting agency whenever any ministrydepartment or any other central government organization makes a request to this effect tiki 8taat hrb qdbirtat tt  nfbqafbnha  tntfri t18ft61faqqlla  ylqiji 1 hiv ’i m llm in1 vivid qfq r it9ft undfqqqfiatml ayn vram university grants commission t3r4t liii hill a jrj ministry of education govt of rldio prof manish r joshi secretary dono2252024cppii 30th may 2024 09 ma 1946 subject free of cost verification of genuineness of the educational certificates 3n€wh4 xdetrhdet as you are aware the verification of educational qualification is a prerequisite for confirmation of the appointed officers in the government service it is necessary in the interest of the government to ensure the genuineness of the candidates and hence it should be the obligation of each educational institute including privatedeemed universities to do this verification free of cost in this regard it is stated that there have been several instances wherein educational institutions demanded fees for the verification of educational certificates of newly recruited assistant section officers drasos through the combined graduate level examination cgle conducted by the staff selection commission ssc the higher education institutions are requested to verify the genuineness of the educational certificates of newly recruited asos in ssc free of cost whenever any ministrydepartment makes a request to that effect to undertake such verification trti xrv ahh th r nfl fbq4fbana it fai iii d1facdido  yidij 1 fv3tr wr qm n mt1 t tiiii bahodur shoh zctor morg nev delhi110002 tith ph  ai 12323628823239337 wn pr 1 elnail secyugc10nicil ffl�� � � � iiittft � prof manish r joshi secretary fno 147 2026arc�� 7c� �  311511� cfil �  jf � cfiq mc1i4suwf � 3ti1ft1t university grants commission �rur � qffif � ministry of education govt of india 19 b  1948  09 april 2026 subject strict compliance with ugc regulations on safety and security of students in higher educational institutions heis reg 311g�oflq llijgql� the university grants commission ugc is committed to ensuring the safety and security of students to ascertain the same ugc has notified and issued various regulations and guidelines from time to time for ensuring the safety security� and wellbeing of students in hlgher educational institutions heis accordingly all hels are advised to strictly comply with the provisions of the following studentcentric ugc regulations and guidelines 1ugc regulations on curbing the menace of ragging in higher educational  ...

# %% [markdown]
# # Stopwords

# %%
from nltk.corpus import stopwords # remove stop words
import nltk
nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

# Tokenize the text after punctuation removal
clean_tokens = word_tokenize(text_no_punct)

filtered_tokens = [word for word in clean_tokens if word not in stop_words]
print(filtered_tokens)
# Out:
# ['hqqrgr', 'a3qtq', 'wlml', 'university', 'grants', 'commission', 'f§rw', 'tvrqq', 'vm', 'nrr', 'ministry', 'education', 'govt', 'india', 'tglhtf', 'asl', 'wt', 'hf', 'em110002', 'bahodur', 'shah', 'zafar', 'marg', 'new', 'delhi110002', 'ph', '01', '12323628823239337', 'fox', '01', '12323', '8858', 'email', 'secyugcnicinrnfqgn', 'fq3ml', 'tht', 'secretary', 'dono', '2252024cppiic144198', '2', 'atv', '1947', '22d', 'january', '2026', 'subject', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificates', 'xtrwrthdttrhorn', 'continuation', 'ugc', 'communication', 'dated', '30th', 'may', '2024', 'regarding', 'verification', 'educational', 'certificates', 'newly', 'recruited', 'assistant', 'section', 'officers', 'drasos', 'combined', 'graduate', 'level', 'examination', 'cgle', 'conducted', 'staff', 'selection', 'commission', 'ssc', 'copy', 'earlier', 'communication', 'attached', 'reference', 'emphasized', 'verification', 'educational', 'qualifications', 'addition', 'prescribed', 'verifications', 'prerequisite', 'confirmation', 'appointed', 'officers', 'government', 'service', 'interest', 'government', 'necessary', 'ensure', 'genuineness', 'candidates', 'therefore', 'obligation', 'educational', 'institute', 'including', 'privatedeemed', 'universities', 'conduct', 'verification', 'free', 'cost', 'therefore', 'centralstatedeemedprivate', 'universities', 'higher', 'education', 'institutions', 'hereby', 'requested', 'undertake', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificates', 'recruitments', 'central', 'government', 'posts', 'irrespective', 'recruiting', 'agency', 'whenever', 'ministrydepartment', 'central', 'government', 'organization', 'makes', 'request', 'effect', 'tiki', '8taat', 'hrb', 'qdbirtat', 'tt', 'nfbqafbnha', 'tntfri', 't18ft61faqqlla', 'ylqiji', '1', 'hiv', '’', 'llm', 'in1', 'vivid', 'qfq', 'r', 'it9ft', 'undfqqqfiatml', 'ayn', 'vram', 'university', 'grants', 'commission', 't3r4t', 'liii', 'hill', 'jrj', 'ministry', 'education', 'govt', 'rldio', 'prof', 'manish', 'r', 'joshi', 'secretary', 'dono2252024cppii', '30th', 'may', '2024', '09', '1946', 'subject', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificates', '3n€wh4', 'xdetrhdet', 'aware', 'verification', 'educational', 'qualification', 'prerequisite', 'confirmation', 'appointed', 'officers', 'government', 'service', 'necessary', 'interest', 'government', 'ensure', 'genuineness', 'candidates', 'hence', 'obligation', 'educational', 'institute', 'including', 'privatedeemed', 'universities', 'verification', 'free', 'cost', 'regard', 'stated', 'several', 'instances', 'wherein', 'educational', 'institutions', 'demanded', 'fees', 'verification', 'educational', 'certificates', 'newly', 'recruited', 'assistant', 'section', 'officers', 'drasos', 'combined', 'graduate', 'level', 'examination', 'cgle', 'conducted', 'staff', 'selection', 'commission', 'ssc', 'higher', 'education', 'institutions', 'requested', 'verify', 'genuineness', 'educational', 'certificates', 'newly', 'recruited', 'asos', 'ssc', 'free', 'cost', 'whenever', 'ministrydepartment', 'makes', 'request', 'effect', 'undertake', 'verification', 'trti', 'xrv', 'ahh', 'th', 'r', 'nfl', 'fbq4fbana', 'fai', 'iii', 'd1facdido', 'yidij', '1', 'fv3tr', 'wr', 'qm', 'n', 'mt1', 'tiiii', 'bahodur', 'shoh', 'zctor', 'morg', 'nev', 'delhi110002', 'tith', 'ph', 'ai', '12323628823239337', 'wn', 'pr', '1', 'elnail', 'secyugc10nicil', 'ffl��', '�', '�', '�', 'iiittft', '�', 'prof', 'manish', 'r', 'joshi', 'secretary', 'fno', '147', '2026arc��', '7c�', '�', '311511�', 'cfil', '�', 'jf', '�', 'cfiq', 'mc1i4suwf', '�', '3ti1ft1t', 'university', 'grants', 'commission', '�rur', '�', 'qffif', '�', 'ministry', 'education', 'govt', 'india', '19', 'b', '1948', '09', 'april', '2026', 'subject', 'strict', 'compliance', 'ugc', 'regulations', 'safety', 'security', 'students', 'higher', 'educational', 'institutions', 'heis', 'reg', '311g�oflq', 'llijgql�', 'university', 'grants' ...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Stemming

# %%
from nltk.stem import WordNetstemming
nltk.download('wordnet')

stemmings = WordNetstemming()

Stemming_tokens = [stemmings.steming(word) for word in filtered_tokens]
print(stemming_tokens)

# %% [markdown]
# # Lemmatizer

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
print(lemmatized_tokens)
# Out:
# ['hqqrgr', 'a3qtq', 'wlml', 'university', 'grant', 'commission', 'f§rw', 'tvrqq', 'vm', 'nrr', 'ministry', 'education', 'govt', 'india', 'tglhtf', 'asl', 'wt', 'hf', 'em110002', 'bahodur', 'shah', 'zafar', 'marg', 'new', 'delhi110002', 'ph', '01', '12323628823239337', 'fox', '01', '12323', '8858', 'email', 'secyugcnicinrnfqgn', 'fq3ml', 'tht', 'secretary', 'dono', '2252024cppiic144198', '2', 'atv', '1947', '22d', 'january', '2026', 'subject', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificate', 'xtrwrthdttrhorn', 'continuation', 'ugc', 'communication', 'dated', '30th', 'may', '2024', 'regarding', 'verification', 'educational', 'certificate', 'newly', 'recruited', 'assistant', 'section', 'officer', 'drasos', 'combined', 'graduate', 'level', 'examination', 'cgle', 'conducted', 'staff', 'selection', 'commission', 'ssc', 'copy', 'earlier', 'communication', 'attached', 'reference', 'emphasized', 'verification', 'educational', 'qualification', 'addition', 'prescribed', 'verification', 'prerequisite', 'confirmation', 'appointed', 'officer', 'government', 'service', 'interest', 'government', 'necessary', 'ensure', 'genuineness', 'candidate', 'therefore', 'obligation', 'educational', 'institute', 'including', 'privatedeemed', 'university', 'conduct', 'verification', 'free', 'cost', 'therefore', 'centralstatedeemedprivate', 'university', 'higher', 'education', 'institution', 'hereby', 'requested', 'undertake', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificate', 'recruitment', 'central', 'government', 'post', 'irrespective', 'recruiting', 'agency', 'whenever', 'ministrydepartment', 'central', 'government', 'organization', 'make', 'request', 'effect', 'tiki', '8taat', 'hrb', 'qdbirtat', 'tt', 'nfbqafbnha', 'tntfri', 't18ft61faqqlla', 'ylqiji', '1', 'hiv', '’', 'llm', 'in1', 'vivid', 'qfq', 'r', 'it9ft', 'undfqqqfiatml', 'ayn', 'vram', 'university', 'grant', 'commission', 't3r4t', 'liii', 'hill', 'jrj', 'ministry', 'education', 'govt', 'rldio', 'prof', 'manish', 'r', 'joshi', 'secretary', 'dono2252024cppii', '30th', 'may', '2024', '09', '1946', 'subject', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificate', '3n€wh4', 'xdetrhdet', 'aware', 'verification', 'educational', 'qualification', 'prerequisite', 'confirmation', 'appointed', 'officer', 'government', 'service', 'necessary', 'interest', 'government', 'ensure', 'genuineness', 'candidate', 'hence', 'obligation', 'educational', 'institute', 'including', 'privatedeemed', 'university', 'verification', 'free', 'cost', 'regard', 'stated', 'several', 'instance', 'wherein', 'educational', 'institution', 'demanded', 'fee', 'verification', 'educational', 'certificate', 'newly', 'recruited', 'assistant', 'section', 'officer', 'drasos', 'combined', 'graduate', 'level', 'examination', 'cgle', 'conducted', 'staff', 'selection', 'commission', 'ssc', 'higher', 'education', 'institution', 'requested', 'verify', 'genuineness', 'educational', 'certificate', 'newly', 'recruited', 'asos', 'ssc', 'free', 'cost', 'whenever', 'ministrydepartment', 'make', 'request', 'effect', 'undertake', 'verification', 'trti', 'xrv', 'ahh', 'th', 'r', 'nfl', 'fbq4fbana', 'fai', 'iii', 'd1facdido', 'yidij', '1', 'fv3tr', 'wr', 'qm', 'n', 'mt1', 'tiiii', 'bahodur', 'shoh', 'zctor', 'morg', 'nev', 'delhi110002', 'tith', 'ph', 'ai', '12323628823239337', 'wn', 'pr', '1', 'elnail', 'secyugc10nicil', 'ffl��', '�', '�', '�', 'iiittft', '�', 'prof', 'manish', 'r', 'joshi', 'secretary', 'fno', '147', '2026arc��', '7c�', '�', '311511�', 'cfil', '�', 'jf', '�', 'cfiq', 'mc1i4suwf', '�', '3ti1ft1t', 'university', 'grant', 'commission', '�rur', '�', 'qffif', '�', 'ministry', 'education', 'govt', 'india', '19', 'b', '1948', '09', 'april', '2026', 'subject', 'strict', 'compliance', 'ugc', 'regulation', 'safety', 'security', 'student', 'higher', 'educational', 'institution', 'heis', 'reg', '311g�oflq', 'llijgql�', 'university', 'grant', 'commission', 'ugc', 'committed',  ...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Word Frequency Analysis

# %%
from collections import Counter
print(Counter(lemmatized_tokens).most_common(20))
# Out:
# [('�', 91), ('programme', 90), ('education', 82), ('student', 68), ('higher', 58), ('institution', 53), ('new', 47), ('country', 47), ('ugc', 45), ('erasmus', 42), ('regulation', 41), ('university', 39), ('academic', 39), ('project', 38), ('partner', 32), ('commission', 31), ('mobility', 31), ('heis', 27), ('grant', 26), ('1', 26)]

# %% [markdown]
# # TF-IDF Vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
print(lemmatized_tokens)
# Out:
# ['hqqrgr', 'a3qtq', 'wlml', 'university', 'grant', 'commission', 'f§rw', 'tvrqq', 'vm', 'nrr', 'ministry', 'education', 'govt', 'india', 'tglhtf', 'asl', 'wt', 'hf', 'em110002', 'bahodur', 'shah', 'zafar', 'marg', 'new', 'delhi110002', 'ph', '01', '12323628823239337', 'fox', '01', '12323', '8858', 'email', 'secyugcnicinrnfqgn', 'fq3ml', 'tht', 'secretary', 'dono', '2252024cppiic144198', '2', 'atv', '1947', '22d', 'january', '2026', 'subject', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificate', 'xtrwrthdttrhorn', 'continuation', 'ugc', 'communication', 'dated', '30th', 'may', '2024', 'regarding', 'verification', 'educational', 'certificate', 'newly', 'recruited', 'assistant', 'section', 'officer', 'drasos', 'combined', 'graduate', 'level', 'examination', 'cgle', 'conducted', 'staff', 'selection', 'commission', 'ssc', 'copy', 'earlier', 'communication', 'attached', 'reference', 'emphasized', 'verification', 'educational', 'qualification', 'addition', 'prescribed', 'verification', 'prerequisite', 'confirmation', 'appointed', 'officer', 'government', 'service', 'interest', 'government', 'necessary', 'ensure', 'genuineness', 'candidate', 'therefore', 'obligation', 'educational', 'institute', 'including', 'privatedeemed', 'university', 'conduct', 'verification', 'free', 'cost', 'therefore', 'centralstatedeemedprivate', 'university', 'higher', 'education', 'institution', 'hereby', 'requested', 'undertake', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificate', 'recruitment', 'central', 'government', 'post', 'irrespective', 'recruiting', 'agency', 'whenever', 'ministrydepartment', 'central', 'government', 'organization', 'make', 'request', 'effect', 'tiki', '8taat', 'hrb', 'qdbirtat', 'tt', 'nfbqafbnha', 'tntfri', 't18ft61faqqlla', 'ylqiji', '1', 'hiv', '’', 'llm', 'in1', 'vivid', 'qfq', 'r', 'it9ft', 'undfqqqfiatml', 'ayn', 'vram', 'university', 'grant', 'commission', 't3r4t', 'liii', 'hill', 'jrj', 'ministry', 'education', 'govt', 'rldio', 'prof', 'manish', 'r', 'joshi', 'secretary', 'dono2252024cppii', '30th', 'may', '2024', '09', '1946', 'subject', 'free', 'cost', 'verification', 'genuineness', 'educational', 'certificate', '3n€wh4', 'xdetrhdet', 'aware', 'verification', 'educational', 'qualification', 'prerequisite', 'confirmation', 'appointed', 'officer', 'government', 'service', 'necessary', 'interest', 'government', 'ensure', 'genuineness', 'candidate', 'hence', 'obligation', 'educational', 'institute', 'including', 'privatedeemed', 'university', 'verification', 'free', 'cost', 'regard', 'stated', 'several', 'instance', 'wherein', 'educational', 'institution', 'demanded', 'fee', 'verification', 'educational', 'certificate', 'newly', 'recruited', 'assistant', 'section', 'officer', 'drasos', 'combined', 'graduate', 'level', 'examination', 'cgle', 'conducted', 'staff', 'selection', 'commission', 'ssc', 'higher', 'education', 'institution', 'requested', 'verify', 'genuineness', 'educational', 'certificate', 'newly', 'recruited', 'asos', 'ssc', 'free', 'cost', 'whenever', 'ministrydepartment', 'make', 'request', 'effect', 'undertake', 'verification', 'trti', 'xrv', 'ahh', 'th', 'r', 'nfl', 'fbq4fbana', 'fai', 'iii', 'd1facdido', 'yidij', '1', 'fv3tr', 'wr', 'qm', 'n', 'mt1', 'tiiii', 'bahodur', 'shoh', 'zctor', 'morg', 'nev', 'delhi110002', 'tith', 'ph', 'ai', '12323628823239337', 'wn', 'pr', '1', 'elnail', 'secyugc10nicil', 'ffl��', '�', '�', '�', 'iiittft', '�', 'prof', 'manish', 'r', 'joshi', 'secretary', 'fno', '147', '2026arc��', '7c�', '�', '311511�', 'cfil', '�', 'jf', '�', 'cfiq', 'mc1i4suwf', '�', '3ti1ft1t', 'university', 'grant', 'commission', '�rur', '�', 'qffif', '�', 'ministry', 'education', 'govt', 'india', '19', 'b', '1948', '09', 'april', '2026', 'subject', 'strict', 'compliance', 'ugc', 'regulation', 'safety', 'security', 'student', 'higher', 'educational', 'institution', 'heis', 'reg', '311g�oflq', 'llijgql�', 'university', 'grant', 'commission', 'ugc', 'committed',  ...

# %% [markdown]
# # Groq Library

# %%
from groq import Groq
import os

client = Groq(
    api_key="api_key", # Directly passing the API key as a string
)

def analyze_document(text):

    prompt = f"""

    You are an AI assistant that analyzes government and educational documents.

    Return output in this format:

    1. Summary (simple English)
    2. Stakeholders (who is affected: students, teachers, admin, government, etc.)

    Document:
    {text}
    """

    response = client.chat.completions.create(
        model="openai/gpt-oss-safeguard-20b", # Updated to a currently supported model
        messages=[
            {"role": "user", "content": prompt}
        ]
    )

    return response.choices[0].message.content

# %%
all_text_truncated = all_text[:25000]  # Further truncating the text to fit within the model's token limit
result = analyze_document(all_text_truncated)
print(result)
# Out:
# **1. Summary (simple English)**
#
# The document contains several circulars and guidelines issued by the University Grants Commission (UGC) of India.
# - **Free certificate verification**: All colleges and universities must check the authenticity of educational certificates of newly hired Assistant Section Officers (ASOs) for Central Government jobs, and they must do this without charging the candidate.
# - **Student safety and welfare**: UGC reminds institutions to follow a list of regulations that protect students from ragging, sexual harassment, and other dangers, and to set up committees (Anti‑Ragging, ICC, Grievance Redressal, etc.) that are publicly listed and run proper grievance‑redressal mechanisms.
# - **Two programmes at once**: New guidelines allow a student to study two full‑time programmes at the same time if the schedules do not clash, or to combine a full‑time programme with an online/ODL one. The rules also define how this applies to different degrees and clarify that past dual‑programme studies remain valid.
# - **Ragging regulations**: The updated Ragging‑Curbing Regulations require students and their parents to sign undertakings affirming they will not rag, and the institutions to maintain proper records.
# - **NCERT becomes a deemed university**: The Ministry of Education, advised by the UGC, has declared NCERT (with six regional units) a “deemed university” under conditions such as no profit‑making, adherence to UGC norms, required accreditation, and compliance with fee and admission rules.
#
# Together, these documents set new responsibilities for higher‑education institutions, clarify rules for student safety, academic flexibility, and administrative procedures, and formalise a major change in the status of NCERT.
#
# **2. Stakeholders**
#
# | Group | Why they are affected |
# |-------|----------------------|
# | **Higher‑Education Institutions** (central, state, deemed, private universities and colleges) | Must perform free certificate verification, establish and maintain committees, implement dual‑programme rules, comply with ragging & safety regulations, and, for NCERT, follow new deemed‑university conditions. |
# | **Students** | Their certificates must be verified without fees; they may pursue two programmes simultaneously; they are protected by ragging, sexual‑harassment and grievance laws; they must sign undertakings about ragging. |
# | **Teachers & Academic Staff** | Must support students in dual programmes, help run committees, and comply with safety & welfare policies. |
# | **Administrative & HR Personnel** | Handle verification processes, committee records, student grievance submissions, and adherence to UGC guidelines. |
# | **Government Ministries/Departments** (e.g., Ministry of Education, SSC) | Rely on verified certificates for hiring, issue requests for verification, and enforce UGC directives. |
# | **Parents/Guardians** | Required to sign undertakings regarding ragging and may need to assist in the verification process. |
# | **Regulatory Bodies** (AICTE, NBA, NAAC, NIRF) | Their accreditation and ranking processes intersect with the new deemed‑university and dual‑programme policies. |
# | **NCERT and its six regional units** | Gain deemed‑university status, must meet the listed conditions, and manage new academic programmes and research. |
# | **Legal/Police Authorities** | May be involved if ragging or other violations occur, following the penal provisions in the regulations. |
#
# These stakeholders must understand and act according to the UGC’s instructions to ensure smooth operation of higher‑education programmes and uphold student safety and credential integrity.

# %%
def analyze_document(text):

    client = Groq(
        api_key="api_key", # Directly passing the API key as a string
    )

    prompt = f"""
        You are an AI document analysis expert.

        Analyze the given document and provide a structured response in simple English.

        IDENTIFY THE CATEGORIES AND DISPLAY IT:
        1.Accreditation
        2.Scholarship
        3.Curriculam
        4.Faculty
        5.Policy
        6.Examination
        7.Admissions

        Impact ANALYZER:
        Extract implications for:
        1.Students
        2.Faculty
        3.Administrators
        4.Institutions
        5.Accrediation / Compliance teams

        SENTIMENT & RISK DETECTION:
        Identify:
        1.Controversial areas
        2.Potential implementation issues
        3.Institutional readiness challenges

        Return the output in this format:

        1. Summary (short and clear)
        2.Identify the categories and display it
        3. Stakeholders
         (● Which stakeholders benefit
          ● Which stakeholders face constraints
          ● New academic or institutional opportunities)
        3. Impact Assessment
         (● Short term ((immediate effects in schools, colleges, administration)
          ● Medium term (Growth + stability)
          ● Long term ((future effects over time))
        4. Impact Analyzer
        5.Awareness & Academic Support
        6.Risks (possible problems, challenges, or negative effects)
        7.Positive and Negative
        8.Governance & Compliance

        Document:
        {text}
        """

    response = client.chat.completions.create(
            model="openai/gpt-oss-safeguard-20b", # Corrected model name
            messages=[
                {"role": "user", "content": prompt}
            ]
        )

    return response.choices[0].message.content

# %%
all_text_truncated = all_text[:25000] # Truncating the text to fit within the model's token limit
result = analyze_document(all_text_truncated)
print(result)
# Out:
# **1. Summary**
# The UGC has issued several circulars and regulations that affect how universities and colleges verify certificates, protect students, run multiple programmes, and manage governance. Key points include:
# • All institutes must verify educational certificates of newly hired government officers **free of charge**.
# • A set of student‑safety and anti‑ragging rules is reinforced, with detailed committee and grievance‑redressal requirements.
# • New guidelines allow students to enrol in **two full‑time programmes** (or one full‑time + one distance/online) simultaneously, provided timing and accreditation rules are met.
# • NCERT has been granted status as a “deemed university” with conditions on finance, programmes, accreditation and credit‑banking.
#
# **2. Identify the categories**
# | # | Category | Evidence from document |
# |---|----------|-------------------------|
# | 1 | **Accreditation** | NCERT deemed‑university conditions, NBA/NAAC accreditation requirement. |
# | 2 | **Scholarship** | *Not directly mentioned* – no scholarship notices in the text. |
# | 3 | **Curriculum** | Guidelines for pursuing two academic programmes simultaneously; NEP‑2020‑inspired curricular flexibility. |
# | 4 | **Faculty** | *No explicit faculty policy* – only indirect mentions (e.g., faculty need to support dual programmes). |
# | 5 | **Policy** | Free‑cost verification, student safety, ragging regulation, dual‑programme policy, NCERT deemed status. |
# | 6 | **Examination** | *Not directly covered* – only reference to certification verification. |
# | 7 | **Admissions** | Dual‑programme admission rules, conditions for NCERT courses, and general compliance with statutory admission norms. |
#
# **3. Stakeholders**
# - **Benefiting**
#   - *Students*: can study two programmes at once, better safety & grievance systems, no extra fee for certificate checks.
#   - *Institutions*: clearer guidelines, potential to attract more enrolments through dual programmes, compliance with national policies.
#   - *Accreditation/Compliance teams*: streamlined requirements for dual programmes and deemed status.
#
# - **Facing constraints**
#   - *Faculty*: increased workload if managing two programmes simultaneously, need to coordinate schedules.
#   - *Administrators*: must set up or strengthen committees, maintain records, handle free‑cost verification logistics.
#   - *Institutions with limited resources*: cost of implementing CCTV, counseling, and digital credit‑banking for NCERT.
#
# - **New opportunities**
#   - *Curriculum designers*: create interdisciplinary pathways.
#   - *Governance bodies*: implement robust grievance mechanisms and anti‑ragging frameworks.
#   - *Institutions*: can launch new online or distance courses under UGC‑approved conditions.
#
# **4. Impact Assessment**
# | Term | Effects |
# |------|---------|
# | **Short‑term** | • Immediate need to set up verification processes for new hires. <br>• Universities must update websites with committee details. <br>• Faculty schedule adjustments for dual programmes. |
# | **Medium‑term** | • Improved student safety culture and grievance handling. <br>• Higher enrolments in dual programmes, leading to increased revenue and academic diversity. <br>• NCERT’s expansion may raise national visibility and attract research talent. |
# | **Long‑term** | • More flexible, interdisciplinary degrees become standard, aligning with NEP‑2020. <br>• Sustained compliance reduces risk of sanctions. <br>• Accumulated data in credit‑banks enhances career‑path planning for graduates. |
#
# **5. Impact Analyzer**
# - **Students** – *Immediate*: free verification saves cost; *Medium*: more choice of programmes; *Long*: broader skill set and career options.
# - **Faculty** – *Immediate*: may need to review curriculum; *Medium*: potential for collaborative teaching across departments; *Long*: opportunities for research integration and interdisciplinary work.
# - **Administrators** – *Immediate*: compliance workload, budget for free verifications; *Medium*: need to train staff for committee functioning; *Long*: institutional reputation improves, attracting funding.
# - **Institutions** – *Immediate*: resource allocation for safety and verification; *Medium*: can leverage dual programmes to fill seat gaps; *Long*: risk of dilution of academic standards if not managed.
# - **Accreditation / Compliance teams** – *Immediate*: new standards to monitor; *Medium*: ensure continuous accreditation of dual programmes; *Long*: maintain a robust framework for emerging educational models.
#
# **6. Awareness & Academic Support**
# - Regular workshops for faculty on dual‑programme coordination.
# - Mandatory e‑learning on ragging and student safety for staff and students.
# - Online portal for students to view verification status and committee records.
# - Clear guidelines and FAQs posted on UGC and university websites.
#
# **7. Risks**
# - **Implementation issues**: Overlapping schedules for dual programmes may create overload; inadequate staff for verification could delay hiring.
# - **Institutional readiness**: Smaller colleges may lack infrastructure (CCTV, counseling) to meet safety regulations.
# - **Controversial areas**: Some may argue that free verification could be misused or that dual programmes dilute quality.
# - **Financial**: Free verification and safety upgrades may strain budgets.
# - **Compliance gaps**: Failure to keep committee details updated online may lead to sanctions.
#
# **8. Positive and Negative**
# - *Positive*: enhanced student choice, stronger safety culture, higher institutional rankings, better data for credit transfer.
# - *Negative*: increased administrative burden, potential scheduling conflicts, risk of under‑resourced support services, possible dilution of academic focus if not managed.
#
# **9. Governance & Compliance**
# - All actions must align with UGC regulations (Curbing Ragging 2009/2013, Sexual Harassment 2015, Student Grievance 2023, etc.).
# - Institutions must upload committee lists and action reports on official websites.
# - Dual‑programme enrolments require approval under the new guidelines and adherence to first‑degree/master regulations.
# - NCERT, as a deemed university, must comply with conditions on non‑commercial activity, accreditation, and credit banking.
#
# *This simple‑English analysis summarizes the document’s main directives, identifies relevant categories, evaluates stakeholder impact, and outlines potential risks and governance requirements.*

# %%
# !pip install -q streamlit
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# !chmod +x cloudflared-linux-amd64
import subprocess
subprocess.Popen(["./cloudflared-linux-amd64", "tunnel", "--url", "http://localhost:8501"])
# !nohup /content/cloudflared-linux-amd64 tunnel --url http://localhost:8501 &
# Out:
# --2026-05-22 04:24:00--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64
# Resolving github.com (github.com)... 20.27.177.113
# Connecting to github.com (github.com)|20.27.177.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2026.5.0/cloudflared-linux-amd64 [following]
# --2026-05-22 04:24:00--  https://github.com/cloudflare/cloudflared/releases/download/2026.5.0/cloudflared-linux-amd64
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/106867604/19374280-4acc-49fd-a5af-eb955320fe42?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-05-22T05%3A16%3A01Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-05-22T04%3A15%3A14Z&ske=2026-05-22T05%3A16%3A01Z&sks=b&skv=2018-11-09&sig=CD%2FncjR%2FfsZzcyzRxRpnXtfKLUlav4H%2FkRsxzvqfFwI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3OTQyNTUwNCwibmJmIjoxNzc5NDIzNzA0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.1mZ2ew0m9W_jls2fuOOaDEQD3itjYMiZQIFE25gpH2E&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream [following]
# --2026-05-22 04:24:00--  https://release-assets.githubusercontent.com/github-production-release-asset/106867604/19374280-4acc-49fd-a5af-eb955320fe42?sp=r&sv=2018-11-09&sr=b&spr=https&se=2026-05-22T05%3A16%3A01Z&rscd=attachment%3B+filename%3Dcloudflared-linux-amd64&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2026-05-22T04%3A15%3A14Z&ske=2026-05-22T05%3A16%3A01Z&sks=b&skv=2018-11-09&sig=CD%2FncjR%2FfsZzcyzRxRpnXtfKLUlav4H%2FkRsxzvqfFwI%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc3OTQyNTUwNCwibmJmIjoxNzc5NDIzNzA0LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.1mZ2ew0m9W_jls2fuOOaDEQD3itjYMiZQIFE25gpH2E&response-content-disposition=attachment%3B%20filename%3Dcloudflared-linux-amd64&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39020697 (37M) [application/octet-stream]
# Saving to: ‘cloudflared-linux-amd64’
#
# cloudflared-linux-a 100%[===================>]  37.21M  65.5MB/s    in 0.6s
#
# 2026-05-22 04:24:00 (65.5 MB/s) - ‘cloudflared-linux-amd64’ saved [39020697/39020697]
#
# nohup: appending output to 'nohup.out'

# %%
# %%writefile app.py
import streamlit as st
import PyPDF2
from groq import Groq

# 🔑 Groq API
client = Groq(api_key="")

# 📄 Extract text from PDF
def extract_text(pdf_file):
    reader = PyPDF2.PdfReader(pdf_file)
    text = ""
    for page in reader.pages:
        page_text = page.extract_text()
        if page_text:
            text += page_text + "\n"
    return text

# 🤖 AI Analysis Function
def analyze_document(text):

    prompt = f"""
    You are an AI document analysis expert.

    Provide:

    1. Summary (short and clear)
        2.Identify the categories and display it
        3. Stakeholders
         (● Which stakeholders benefit
          ● Which stakeholders face constraints
          ● New academic or institutional opportunities)
        3. Impact Assessment
         (● Short term ((immediate effects in schools, colleges, administration)
          ● Medium term (Growth + stability)
          ● Long term ((future effects over time))
        4. Impact Analyzer
        5.Awareness & Academic Support
        6.Risks (possible problems, challenges, or negative effects)
        7.Positive and Negative
        8.Governance & Compliance

    Document:
    {text}
    """

    response = client.chat.completions.create(
        model="openai/gpt-oss-safeguard-20b",
        messages=[{"role": "user", "content": prompt}]
    )

    return response.choices[0].message.content


# 🎯 STREAMLIT UI
st.title("📄 AI PDF Document Analyzer")
st.write("Upload a PDF to get AI-powered analysis")

uploaded_file = st.file_uploader("Upload PDF", type=["pdf"])

if uploaded_file is not None:

    st.success("PDF Uploaded Successfully!")

    # Extract text
    text = extract_text(uploaded_file)

    if st.button("Analyze Document 🚀"):

        with st.spinner("Analyzing with AI..."):
            result = analyze_document(text)

        st.subheader("📊 Analysis Result")
        st.write(result)
# Out:
# Writing app.py

# %%
# !streamlit run /content/app.py &>/content/logs.txt &

# %%
# !grep -o 'https://.*\.trycloudflare.com' nohup.out | head -n 1 | xargs -I {} echo "Your tunnel url {}"
# Out:
# Your tunnel url https://hourly-veterinary-russell-kits.trycloudflare.com

# %%
# %%writefile requirements.txt
# streamlit
# PyPDF2
# Groq
# Out:
# Writing requirements.txt
